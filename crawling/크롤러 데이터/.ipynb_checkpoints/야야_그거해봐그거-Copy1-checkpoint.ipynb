# %%
import pandas as pd
a = pd.read_csv('place_reviews.csv')
a
# Out:
#      place_name                                 review
# 0      이호테우해수욕장                                말 필요 없음
# 1      이호테우해수욕장     이호테우 해변 비오는 날 방문했는데 운치있고 넘 좋네요!!!!
# 2      이호테우해수욕장                         좋았어요 ㅎㅎ 말등대도보공
# 3      이호테우해수욕장  귀여운 말등대가 있는 해수욕장🪅아이들 놀기 좋은 해수풀장이 있어요~
# 4      이호테우해수욕장                            제주도 마지막 여행지
# ...         ...                                    ...
# 4186    해거름마을공원              풍경 좋아요 잠깐 쉬어가기 좋은 카페도 있어요
# 4187     노형근린공원     공원 강아지랑 걷기도 좋고 넓고 숲도 많아서 자연구경 딱좋아요
# 4188       서복공원                                조금 아쉽네요
# 4189       서복공원             정방폭포 봤다면 여기까지 둘러보기~ 정원 굿~~
# 4190     수운근린공원                    윗몸일으키기 시설이 있어서 좋아요.
#
# [4191 rows x 2 columns]

# %%
b = pd.read_csv('place_data.csv').drop('관광지 이름', axis = 1)
b
# Out:
#     place_name                        place_location place_feature place_star  \
# 0     이호테우해수욕장              제주특별자치도 제주시 이호일동 1665-13       해수욕장,해변       3.8점
# 1       남원큰엉해변  제주특별자치도 서귀포시 남원읍 태위로 522-17 (우)63620       해수욕장,해변       4.5점
# 2       함덕해수욕장    제주특별자치도 제주시 조천읍 조함해안로 525 (우)63333       해수욕장,해변       4.5점
# 3       협재해수욕장   제주특별자치도 제주시 한림읍 한림로 329-10 (우)63011       해수욕장,해변       4.6점
# 4        용머리해안                  제주특별자치도 서귀포시 안덕면 사계리       해수욕장,해변       4.6점
# ..         ...                                   ...           ...        ...
# 784     수산체육공원     제주특별자치도 서귀포시 성산읍 수송로 144 (우)63630        도시근린공원        NaN
# 785      삼매봉공원                  제주특별자치도 서귀포시 서홍동 821            공원        NaN
# 786       숨골공원                 제주특별자치도 서귀포시 서호동 1609            공원        NaN
# 787     젊은이의광장                       제주특별자치도 제주시 건입동        도시근린공원        NaN
# 788   신풍 레포츠공원    제주특별자치도 서귀포시 성산읍 남산봉로 247 (우)63636        도시근린공원        NaN
#
#     operating_time
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4    09:00 ~ 17:00
# ..             ...
# 784            NaN
# 785            NaN
# 786            NaN
# 787            NaN
# 788            NaN
#
# [789 rows x 5 columns]

# %%
import pandas as pd
import re

# 예시 데이터프레임 생성
data = b
df = pd.DataFrame(data)

# 정규 표현식을 사용하여 (우)와 숫자를 포함한 부분을 제거
df['place_location'] = df['place_location'].apply(lambda x: re.sub(r'\(우\)\d+', '', x))

df
# Out:
#     place_name                place_location place_feature place_star  \
# 0     이호테우해수욕장      제주특별자치도 제주시 이호일동 1665-13       해수욕장,해변       3.8점
# 1       남원큰엉해변  제주특별자치도 서귀포시 남원읍 태위로 522-17        해수욕장,해변       4.5점
# 2       함덕해수욕장    제주특별자치도 제주시 조천읍 조함해안로 525        해수욕장,해변       4.5점
# 3       협재해수욕장   제주특별자치도 제주시 한림읍 한림로 329-10        해수욕장,해변       4.6점
# 4        용머리해안          제주특별자치도 서귀포시 안덕면 사계리       해수욕장,해변       4.6점
# ..         ...                           ...           ...        ...
# 784     수산체육공원     제주특별자치도 서귀포시 성산읍 수송로 144         도시근린공원        NaN
# 785      삼매봉공원          제주특별자치도 서귀포시 서홍동 821            공원        NaN
# 786       숨골공원         제주특별자치도 서귀포시 서호동 1609            공원        NaN
# 787     젊은이의광장               제주특별자치도 제주시 건입동        도시근린공원        NaN
# 788   신풍 레포츠공원    제주특별자치도 서귀포시 성산읍 남산봉로 247         도시근린공원        NaN
#
#     operating_time
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4    09:00 ~ 17:00
# ..             ...
# 784            NaN
# 785            NaN
# 786            NaN
# 787            NaN
# 788            NaN
#
# [789 rows x 5 columns]

# %%
df.to_csv("place_data.csv", mode='w')

# %%
c = pd.read_csv('place_data.csv')

# %%
c
# Out:
#      Unnamed: 0 place_name                place_location place_feature  \
# 0             0   이호테우해수욕장      제주특별자치도 제주시 이호일동 1665-13       해수욕장,해변
# 1             1     남원큰엉해변  제주특별자치도 서귀포시 남원읍 태위로 522-17        해수욕장,해변
# 2             2     함덕해수욕장    제주특별자치도 제주시 조천읍 조함해안로 525        해수욕장,해변
# 3             3     협재해수욕장   제주특별자치도 제주시 한림읍 한림로 329-10        해수욕장,해변
# 4             4      용머리해안          제주특별자치도 서귀포시 안덕면 사계리       해수욕장,해변
# ..          ...        ...                           ...           ...
# 784         784     수산체육공원     제주특별자치도 서귀포시 성산읍 수송로 144         도시근린공원
# 785         785      삼매봉공원          제주특별자치도 서귀포시 서홍동 821            공원
# 786         786       숨골공원         제주특별자치도 서귀포시 서호동 1609            공원
# 787         787     젊은이의광장               제주특별자치도 제주시 건입동        도시근린공원
# 788         788   신풍 레포츠공원    제주특별자치도 서귀포시 성산읍 남산봉로 247         도시근린공원
#
#     place_star operating_time
# 0         3.8점            NaN
# 1         4.5점            NaN
# 2         4.5점            NaN
# 3         4.6점            NaN
# 4         4.6점  09:00 ~ 17:00
# ..         ...            ...
# 784        NaN            NaN
# 785        NaN            NaN
# 786        NaN            NaN
# 787        NaN            NaN
# 788        NaN            NaN
#
# [789 rows x 6 columns]

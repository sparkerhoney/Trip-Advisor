# %% [markdown]
# # 전체 크롤링 코드

# %%
import os
import csv
from time import sleep

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

##############################################################  ############
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')
chromedriver_path = "C:/chromedriver"
driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기

reviews = []  # 중복 리뷰를 저장하지 않기 위한 리스트 생성

def main():
    global driver, load_wb, review_num

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

    # 검색할 목록
    place_infos = [input("")]

    for i, place in enumerate(place_infos):
        # delay
        if i % 4 == 0 and i != 0:
            sleep(5)
        print("#####", i)
        search(place)
        
    # 저장된 리뷰를 CSV 파일에 저장
    save_to_csv(place, reviews)
        
    driver.quit()
    print("finish")

def search(place):
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem') # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, place_lists)
    search_area.clear()

    # 우선 더보기 클릭해서 2페이지
    try:
        driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
        sleep(1)

        # 2~ 5페이지 읽기
        for i in range(2, 6):
            # 페이지 넘기기
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
            sleep(1)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            place_lists = soup.select('.placelist > .PlaceItem') # 장소 목록 list

            crawling(place, place_lists[:5])

    except ElementNotInteractableException:
        print('not found')
    finally:
        search_area.clear()

def save_to_csv(place, reviews):
    file_name = f"{place}_reviews.csv"
    with open(file_name, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['review']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for review in reviews:
            writer.writerow({'review': review})
            print(f"{file_name} saved.")


def crawling(place, place_lists):

    while_flag = False
    for i, place in enumerate(place_lists):
        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address

        detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
        driver.find_element_by_xpath(detail_page_xpath).send_keys(Keys.ENTER)
        driver.switch_to.window(driver.window_handles[-1])  # 상세정보 탭으로 변환
        sleep(1)

        print(i+1,'.', place_name)

        # 첫 페이지
        extract_review(place_name)

        # 2-5 페이지
        idx = 3
        try:
            page_num = len(driver.find_elements_by_class_name('link_page')) # 페이지 수 찾기
            for i in range(page_num-1):
                # css selector를 이용해 리뷰 페이지 찾기
                driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name)
                idx += 1
            driver.find_element_by_link_text('후기 더보기').send_keys(Keys.ENTER) # 버튼 누르기
            sleep(1)
            extract_review(place_name) # 리뷰 추출
        except (NoSuchElementException, ElementNotInteractableException):
            print("no review in crawling")

        # 그 이후 페이지
        crawl_next_reviews(place_name)

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환

def extract_review(place_name):
    global driver, reviews # reviews 리스트를 사용하기 위해 global로 선언
    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 현재 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')

    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        for i, review in enumerate(review_lists):
            comment = review.select('.txt_comment > span')  # 리뷰
            if comment:
                comment_text = comment[0].text.strip()  # 공백 제거
                if comment_text and comment_text not in reviews:  # comment_text가 비어있지 않고 중복이 아닌 경우에만 출력
                    reviews.append(comment_text)  # 중복이 아닌 리뷰를 reviews 리스트에 추가
                    print(comment_text)
    else:
        print('no review in extract')
        ret = False

    return ret

def crawl_next_reviews(place_name):
    global driver
    max_clicks = 200# 최대 클릭 횟수 설정
    click_count = 0 # 현재 클릭 횟수 초기화
    while click_count < max_clicks:
        try:
            driver.find_element_by_link_text('후기 더보기').send_keys(Keys.ENTER)  # 후기 더보기 버튼 클릭
            sleep(1)
            if not extract_review(place_name):  # 리뷰 추출
                break
            click_count += 1  # 클릭 횟수 증가

        except (NoSuchElementException, ElementNotInteractableException):
            print("no more reviews to load")
            break

            
            
if __name__ == "__main__":
    main()
# Out:
# 함덕해수욕장
# ##### 0
# 1 . 함덕해수욕장
# 제주에서 젤 좋아하는곳💙
# 예뻐요..조아요..
# 일출명소 물놀이 나들이 진짜 바다 색감이 최고!!!!!
# 바람이 심하게불어서 모래가 많이 날리긴했지만,물맑고 분위기 너무좋았음
# 함덕.에메랄드빛 해변.최고캠핑하는사람들 쓰레기 처리잘해라 좀!!
# 처음으로 찾은 함덕해수욕장은 주차장이 작아서 주차가 힘들었고, 주차 후 해수욕장까지 걸어서 1~2부정도 걸어야 보였고, 백사장은 작고, 해수욕장 앞에 횟집들이아닌 편의점,커피숍,호프집,음식점등 다양하게 근접해있다는 점이 좋았습니다 하지만 힐링할곳은 아니고 한번 놀러가볼만한곳으로 다녀오는걸 추천합니다.
# 편의시설과 인파 적당하고 수심 아이가놀기좋고 소라게 보말등 생물잡기 고운모래놀이 수영 모두 가능함.버스도 자주 다녀서 대중교통 이용 가능
# 최고입니다. 또 올겁니다.
# 바다색이 미쳤음 내가 갔을 땐 바다도 잔잔하고 좋았음 근데 사람이 좀 많음
# 함덕 가신다면 스타벅스보다 해수욕장 바로 앞에 있는 카페 가길 추천 드러요 뷰가 좋거든여   맛보장은 못드려요
# 따로 찾아서 올만한 곳 입니다.바닷가랑 가까운 곳에 주차장도 별도로 있구요.
# 서쪽에 협재해수욕장 이라면 동쪽으로는 함덕인듯. .너무 멋지고 바다 가운데 섬처럼 썰물때는 드러나는 모래섬으로 산책도 할수있고 조성도 잘되어 있고 주변 상권도 잘조성되어 있다...깨끗하고 예쁘다...막상 산책다니고 4일을 머물렀는데 해변사진은 몇장없네...다시 찾게될 바다~
# 나들이
# 체고 ,,
# 제주에서 제일 이쁜 바다뷰에 주차까지 좋았음.
# 바다빛깔 넘 예뻤어요 🫰
# 예뻐요
# 이쁨
# 내가 너무나 애정하는 해수욕장❣️바다색도 최고 예쁘고, 사부작 사부작 거닐며 산책하기에도 좋은 곳 :)
# 행복했다 ‼️
# 1년한번가는 제주도  헤헤  또가고싶다
# 여수보다 다시 찾고 싶은 밤 바다
# 바다도 하늘도 미쳤다
# 아주 좋아요 가을에가도 물놀이 물놀이 물놀이 할 수 있어요
# https://youtu.be/egjck4nZ4w0ok차박 함덕해수욕장 유튜브 검색하시면 동영상 올렸습니다 여러편과. 아름다운해변 드론영상도 있습니다
# 아름다운 에메랄드 빛 바다색. ^^
# 이게 제주 바다다!!!
# 함덕해변 너무 예뻐요... 흐려도 새벽에도 저녁에도 언제나 아릅답네요 처음 와봤는데 베스트가 될것 같습니다
# 그립다아
# 해물이 신선하고 조개살이 신선해서 달고 맛있어요 주아주머니 도 친절하셔요
# 올레길 19코스를 역으로 걸으면 이 해변의 아름다움을 찬란하게 맞이할 수 있다.
# 2022.08. 바닷가와 주변상가가 거의 붙어 있는 곳. 숙소만 잘 해결하면, 먹고 쉬고 놀기 좋은 위치.
# 옆 김녕바다 텃세에 제대로 실망해서 여기왔는데 여긴 그나마 괜찮네요
# 제주 바다는 밀물때 오면 좋아요~ 쌀물과 밀물의 차이가 엄청큽니다.
# 사람 밭
# 무조건 가시면 함덕해수욕장  바로앞 말고  오른쪽으로 쭉가면 주차장도 있고 더 좋은곳있습니다.정면은 물이 탁하고 물고기 없으니정면말고 오른쪽으로 쭈욱가셔서 물시원하고 깨끗한곳으로 가셔요 물고기 더 많아요! 스노쿨링 하시려면 오른쪽으로 가셔야해오 ^_^
# 각설이만 아니면 노을뷰가 예뻐보였을것이다노래가 시작되자마자 산통을 다 깸여기가 할머니할아버지들 오는 해수욕장인가?
# 아침엔 물이 맑고 오후엔 북한강 똥물이 되어요가족단위가 대부분이라 아이들이 많아요물들어올때 옹기종기 좁은 곳에 많은 사람들이 모여 놀아서 수영 물놀이를 제대로 할 수 없어서 저는 물 나갔을때가 놀기 좋아요월정리는 파라솔 2만원 종일 대여인데여기는 3만원 6시까지네요액티비티 하게 기구 타고 놀 수도 잇고옷이나 산드비치타올 등등 파는 천막들이 잇는 게 좋았어요 다만 이 근처에는 맛 집이 없네요스벅이 제일 좋았어요해변은 왼쪽 오른쪽 두 곳이 잇는데 느낌이 조금 달라요
# 애들이 너무 많고 싱글이 놀기엔 좀그럼! 해변은 이쁨니당
# 내가 제주도에서 가장 사랑하는 해변
# 밀물과 썰물의 차이가 엄청 커서 썰물 때는 물 한번 밟으려면 몇 백 미터를 가야 했습니다.
# 너무나 예쁜 해수욕장.
# 엄청 큰 해변가는 아니지만, 소소하게 놀기 좋은 해수욕장 아름다움!
# To my knowledge the most beautiful beach in Korea.
# 물놀이하기 제일좋은곳 같네요~~~모래도 곱고 물도이쁘고~~!!
# 오후 늦게 방문 일몰까지 보고 왔습니다.주변 부대시설 많고, 서우봉도 잠깐 오르기 좋아요.사람이 많아서 번잡스러운 느낌은 있습니다.
# 바다 너무 예쁜데 발 씻는 곳이 모래에 막혔어
# 함덕은 뭐 :)
# 이쁘고좋은데 몇미터두고도 날씨오락가락. 사람ㅂ많고 모래바람따갑. 얕아서수영하긴좋음 바다색 예쁨
# 해수욕장 분위기가 너무 좋아
# 함덕  멋져요..
# 바닷물 색깔이 아름답고 깨끗해보여서 너무 좋다.
# 주변 카페 많고, 주차 편함이쁜거로 따지면 최고의 해변!
# 동쪽 해수욕장에서 가장 사람많고 제일 번화가 버스킹도 해서 낭만적인곳 그래도 물 하나는 너무 너무 말고 아름다움 노을도 이쁨
# 아이들 놀기 좋아요ㅎ
# 물미역만 아니면 수심도 얕고 물놀이하기 딱이겠는데 물미역 밉다 ㅠ그리고 많이 상업화된 느낌이 짙어서 한적한 휴양지를 원하는 나로썬 애월이나 곽지쪽을 선호.
# 아이들과 즐기기엔 좋은 해수욕장이었어요.풍경이라던가 편의 시설(발 닦는 곳)이 잘 되어 있어 정말 좋았습니다.
# 에메랄드 바다ㅜㅜ 꼭 가보세요 신발벗고 들어가도 지금보이는 찰랑찰랑한 부분은 발목까지의 깊이밖에 안돼요 안에 들어가면 모래사장이 또 있어서 거기다 삼각대 놓고 찍으면 돼요 사진 진짜 이쁘게 나와요 추천합니다!
# 굳
# 왜 유명한지 알 것 같습니다
# 서우봉 꼭 가세요 !! 힘들게 오름 올라가는거보다 백배 추천
# 바람이 거센 함덕 해수욕장!
# 보고만 있어도 좋음 ㅠ
# 물색 너무예쁨 모래사장 경사도 낮아서 물놀이하기 너무 좋을 것 같다
# 어제 태풍급 강풍이라고 뉴스 나올 정도로 날씨가 험해서 오늘도 흐리고 바람이 강했는데, 바닷물이 맑고 탁 트인 전경이 좋았어요. 맑은 날 또 와야겠다고 다짐했습니다 ㅎㅎ
# 정말 최고 입니다 물 맑고 애들 놀기 좋음
# 바다 예쁨. 바람 개많이 불어서 날라가는 줄 알았음.
# 역시 제주바다는 ㅈㄴ 예쁨
# 유명세보다 별로
# 이뻐요
# 또가고싶어여 스타벅스에서 제주에서만 맛볼수있는 메뉴 꼭 먹어줘야죠 쑥떡 프라푸치노!
# 주변에 먹거리 많구 활기차고 넓은 해수욕장이에요. 노을 질 때도 참 예쁜 곳이구요. 주차장도 넓은 편이고 시설이 잘 되어 있어요. 마켓도 열리고 야외공연도 있구 패러글라이딩같은 것도 하시구 장난감도 팔구...잔디밭에 돗자리 깔아서 바다 보여요. 피크닉해도 좋고. 굳이 돗자리 없어도 돼요. 앉을 수 있는 계단이 있어요. 모래가 엄청 엄청 곱고 부드러워요. 쑥쑥 발이 들어가요. 아이들 놀기에도 참 좋아요.
# 아름다워요~그날은 내 인생에 최고의 노을을봤어요~완전해운이었죠
# 예쁘다 예뻐
# 최고
# 밤에도 낮에도 구경하기 좋은곳 물이 엄청 맑아유
# 최고..!!
# 최고예요
# 큰딸아이와 여행을 했는데 깜빡하고 두고 왔나 봅니다
# 외국 해변 느낌으로 예뻐요
# 에메랄드 빛 아름다운 해변 우리나라에도 이런 곳이 있어서 너무 좋아요
# 바다색 정말 예뻐요 ㅠㅠ 그리고 주변에 프랜차이즈 가게들도 많아서 편해요!! 8월 말 기준 편의점에서 물놀이 용품도 팔더라고요 그리고 해수욕장 막을 때는 샤워시설도 안하는 것 같으니까 잘 찾아보고 가세요!!
# 에메랄드란 이런 거구나 느끼게 해준 바다. 스노클링 하기에도 좋아요.
# (금줄 영역이 3~5m 가량으로 너무 좁아 스노클링이나 오리발 불가) 경치도 좋고 모래사장은 넓은데 바다 개방을 너무 좁게 설정해서 그냥 나왔다.안전줄 영역이 너무 좁아서 스노클링은 할 수 없고 오리발도 찰 수 없다.너무 영역이 좁아서 옆사람과 금세 만난다...뷰는 좋아서 사진 찍기 좋을 듯
# 그냥 몰디브가 따로 없는 뷰..
# 굿
# 제주 최고 해수욕장
# 물빛이 에메랄드빛이네요수심이 낮아서 위험하지않고 모래도 부드럽고산책개념으로 둘러보러왔는데 정말 좋아요여름이라 사람들이 정말 많네요코로나만 아니면 최고의 휴양지같은 느낌 이에요
# 바다랑 야자수나 다 이쁜데 넘 이쁜데..사람이 노무 많습니다,,, 마스크 안끼고 수영 많이들 하시네요..1분도 안돼서 나옴
# 해수욕하기 좋아요
# 아이들과 놀기 너무 좋아요
# 주차장에서 차 빠지는거 기다리고 있는데 관리하는 분이 자기 땅이라고 나가라고 하시네요^^자기 땅이면 그래도 되는지 참^^
# 정말 좋아노을지는 게 아름다웠어요
# 바다색깔이예쁩니다둘레걷기좋음
# 너무 유명함
# 제주 top2 해변 ㅠㅠ협재랑 함덕이 제일 이쁨주변 배경 (야자수 등등) 고려하면 넘버원 가넝
# 나의 기준에서도 제주 최고의 해변은 함덕, 두번째는 중문색달...세번째는 성산일출봉이 보이는 광치기해변...나머진 그닥
# 내기준 제주도 최고, 최애 해변 델문도 옆 해변 주로 관광객서우봉 옆 해변 주로 제주도민
# 너무 조아요 최고의 스타벅스!!
# 에메랄드빛 해변, 수영하기에도 좋음
# good job
# 제주에서도 손꼽히는 해수욕장예전부터 유명했던 곳이라 주변 먹거리, 숙박 잘 돼있음
# 이국적이고 깔끔한 함덕 최구^^
# 잘 정돈된 해수욕장. 가족이 오기에 좋을 듯레저를 하려면 이호테우나 월정리가 나을듯하다.
# 사진으로는 못 담는 맑은 바다,, 제주 바다 중에 가장 예쁜 것 같아요! 하지만 너무 관광지..
# 바다도 맑고.  이쁘고 주변에 공원 같이 조성한 곳도 좋음
# 함덕바닷가에서 보는 유채꽃 서우봉이 멋질  터!
# 너무 좋았어요~~~! 다시 가고 싶네요^^
# 완전 투명하고 예쁜 바다!!!
# 제주바다중 최고일듯. 해변도 크고 바다색도 좋고.
# 물색이 에메랄드빛 너무 예뻐요
# 바다는 이쁜데 주변 건물들이 별로. 제주스러움이 없다
# 제주도 바다 중 젤 좋아하는 곳
# 바다예쁨
# 말이 필요없는 곳 입니다
# I love Hamdeok...
# 바람 많이 불어 지금은 넘 추워요 따숩게 입고 가세여
# 물색깔 존예
# 모든것을 갖춘 해변은 함덕이 아닐까요..아름답고 또 아름다운 곳하루 놀긴 아쉽고 늘 연박하고 갑니다
# 노을질때 너무 예쁘고 해변앞에 놀 곳이 많아서 좋았습니다. 부산 해운대처럼 번화한 곳이더라구요. 여름에 또가고싶네요. 한적한 제주의 다름 해변들과 다르게 핫한곳! 예쁜 소품샾들이 많아서 더좋아용
# 사람이 많긴 한데 진짜 너무 예뻐요. 제주도는 내리는 곳 마다 뷰 맛집이네요 밥먹고 잠깐 들린 곳이라 기대 안하고 갔는데 진심 이뻐요
# 사람 많은 함덕그래도 오늘은 좀 적은편이었어요.제주에 모든 바다는 다 가봐서 눈이 높은데 ㅋㅋ함덕은 역시 함덕이네요.
# 해변 아기자기해서 귀엽고 올리브영/ 스벅 있어서 언제가도 평타는 침.
# 바다는 그럭저럭인데...파라솔 펴놓고 바가지요금 극악!!! 동네 양아치들이  개인 그늘막도 못치게 함!!!
# 좋네요
# 외쿡느낌나요!!
# 강추!
# 근데 사람 많음
# 뷰 좋음 해변 규모와 주차공간 작음
# 해변이 너무 좁아서 성수기에는 바추임. 비수기 평일에 가면 좋은 곳. 파도가 너무 없어서 물놀이 재미는 없고 아이들과 가거나 바다 수영 연습하기 좋은 곳. 물이 깨끗해 보이지만 화장실이 바로 해변 뒤라... 거친 현무암 갯바위가 있어서 물놀이 시에 사고 위험 있슴.
# 아이들이랑 가기 좋음..
# 좋아요
# 해변도 좁고 흙탕물에 쓰레기 둥둥 너무 별로임 거기에 온수샤워장도 없음 진짜 최악!! 며칠 전 갔던 협재 해수욕장이랑 넘 비교됨 여기 다신 올 일 없을듯
# 언제나 최고
# 애매랄드빛 물빛.
# 애월바다보다 우도바다보다 협재보다함덕바다가 에메랄드빛..제일예뻐요!
# 밤에 가도 너무 좋았어요
# 주차공간도 많고 바다도 크고 굿굿!!
# 가족들이랑 놀기 젤좋은 해수욕장같아요.
# 해수욕장이 넓은편이고 물수위도  얕음 전망좋은 곳에 규모 큰 카페있고 주변 해수욕장 에 비해 사람들이 많아보임
# 애월쪽 거친 바다와는 다른 느낌. 잔잔한 게 또 다른 매력.
# 물도 맑고 해변 카페도 좋다
# 어릴적 나의고향 함덕...  이곳이 개발되지 말기를...
# 넘멋진곳이에요~^^
# 참 예뻐요초록한 잔디밭에 금빛 모래사장 너머로에메랄드빛 찬란한 바다체고
# every thing
# 제주도 최애 해변
# 더운날엔 역시 바다로 가야죠
# 고즈넉한 해수욕장
# La 뺨치게 좋고 아름다운 곳
# 제주에서 가장 넓고 예쁜바다.바다도 보고 다크투어리즘중이라 너븐숭이4.3 기념관도가고 그 근처에 걸어갈 수 있는 공간사진관에서 사진도 남겼어요.
# 정말 이뻐요!제주도에 또 오면 꼭 재방문할 것 같아요.오늘 비도 오고 바람도 너무 많이 불어서 춥고.. 추웠지만 사진도 이쁘게 잘 나오고 즐거운 시간 보내서 행복했어욤카페가 정말 이쁜데 근처만 가고 들어가보진 않았어요.저 멀리 새들도 많이 보이고 정말 좋았어요ㅎㅎ
# 바람이 너무 많이 불어서 춥고 힘들긴 했는데 좋았어요. 하얀모래해변이 너무 예뻐요
# https://youtu.be/KXTWTQ-Qwug제주해수욕장, 함덕서우봉해변, 한천,열안지오름
# 델문도 옆길로 쭉 가다보면 바다와 만날수 있어요
# 다른 해변보다 저는 여기가 제일 ㅠ 좋아요ㅠ
# 다른 해변이 너무 예뻐서 묻힘
# 저번에 해질무렵 너무 이뻐서이번에는 아예 바로앞에 숙소 잡았어요
# 해수욕장은 갠춘했는데, 샤워장 현금박치기 개짜증나더라구요. 시에서 운영하는건지는 모르겠는데 카드 안되는거 넘 꼴배기 싫었습니다. 왜안되냐고 하니까 퉁명스럽게 리더기 없다고 ㅋㅋ 그래서  이용안했어요. 개꼴배기 싫네 신고하러갑니다.
# 작년엔 에메랄드빛깔이었는데 올해는 미역밭이네요 흙탕물에 서해바다보다 못해요 아이들이랑 갔는데 못들어가고 차라리 서우봉해변 또는 월정리해변으로 가세요
# 제주도에 올때마다 오는데 좋습니다 여름에는 물이 좀 미지근하네요 ^^
# 너무 좋아서 올해 또 왔어요
# 해수욕장이 개장되는 여름에는 정말 가기 싫습니다. 이쁜 해변은 사람들로 북적거리고 파라솔 설치하라고 강요하는 각박한 장사속, 예뻤던 카페 옆에 있는 조개 구이집에서 하루 온 종일 노래방 기계설치해서 고성방가 수준으로 질러 댑니다. 이뻤던 해안이 젓가락 장단 맞추던 80년대 유원지가 되어 버렸습니다. 두번 다시는 안갑니다.
# 멀리서 보면 아름다움. 아 이래서 함덕이라고 하는구나...물속에 들어가면 온갖 기름때, 미역같은 해조류, 초코렛바 껍질 쓰레기...해수욕장 주변은 돗대기 시장... 주차하는데 20분...제주도에 해수욕장 많습니다.함덕은 봄 가을에나 생각하시길. 여름엔 너무 아닌듯요. 제대로 실망
# 깨끗하고 예쁜 바다. 여러 개 추억이 있는 곳.
# 진짜 너무 예쁜 곳
# 오끼나와 바다 같은곳~ 숨겨진 명소~
# 곳곳에 야자수와 탁트인 에메랄드빛 바다
# 날씨는 흐렸지만 바다는 너무 예쁨 ㅠㅠ
# 시원한 바다다다다!
# #함덕해수욕장#해변을거닐며#아름다운바다와자연에흠뻑빠져들다~^^
# 바다색이 너무나 아름답고 바다에 다다르기 까지의 길도 예뻐요. 특히 바다가 아기자기해서 그것만의 매력이 있습니당.: )
# Healing
# 넓음. 멋짐. 사람 많음.
# 함덕해수욕장
# --
# 고운 모래와 맑은 바다. 푸른 언덕까지 예쁜 해변
# 협재보다 덜 유명한데 이유를 모르겠다.
# 동해에서는 한번도 보지 못한 빛깔과 끝없이 들어갈 수 있는 얕은 바다. 이국적이다. 에메랄드 빛은 협재가 더 강하지만 함덕이 보다 정돈된 느낌이고 시장바닥같은 분위기가 덜하다.
# no more reviews to load
# 2 . 함덕해수욕장 주차장
# 주차장 넓고 좋습니다
# no review in crawling
# no more reviews to load
# 3 . 함덕해수욕장 야영장
# 관리인 생김/알박기 차단해주심대신에 언제 나갈지 일정확인하심솔직히 한 2만원 받는게 나을듯(너무 그간 관리가 안되었음)모닥불 불가능 숯불/조리는 가능여름에 박터질듯^^... 화장실 개수대 있어서 편리하지만 바다 앞자리는 거의 하늘의 별따기
# 알박기 많은것 같습니다. 버려진텐트인지 알수없네요.ㅡㅡ
# 야영장
# no review in crawling
# no more reviews to load
# 4 . 함덕해수욕장 아영장 공중화장실2
# 여기 앞에서 머리 자르고 모래에 머리카락 버리고 간 남자(50-60대로 보임)진짜 제발 그러지좀 마세요..에휴 진짜 왜그러는지..
# 약간 지저분함... 발씻을 곳 부족하고 물이 방울방울 질질질... 불편했슴.
# no review in crawling
# no more reviews to load
# 5 . 파리바게뜨 함덕해수욕장점 전기차충전소
# no review in extract
# no review in crawling
# no more reviews to load
# 1 . 에이바우트커피 함덕해수욕장점
# 커피 맛은 솔직히 ^^; 메가커피보다도 맛이 없지만 이 가격에 홀을 이용할 수 있다는 것이 장점인 것 같아요 무엇보다 바로 앞이 바다라서 개방감을 느낄 수 있어요. 에이바우트 응원합니다!
# 뷰는 너무 좋은데 직원분 친절도가 심각할 정도로 별로입니다...
# 위치만 좋다
# 커피류, 스무디류, 디저트류를 저렴한 가격에 즐길 수 있습니다. 특히, 커피는 무려 2,900원의 저렴한 가격인데.. 그렇다고 싸구려 동네 수준은 아닌 것 같습니다.2층으로 가시면 바로 옆 스타벅스 부럽지않은 시설과 함덕해변의 풍경을 정면에서 즐기실 수 있습니다.해변뷰와 충분한 충전기들, 인테리어를 고려한다면 커피를 한잔 더마셔야 하는게 아닌가 싶었습니다.
# 2900원 아메리카노에 이 정도 뷰면 매우 감사하죠
# 매장 분위기 좋고 깔끔하고 다 좋은데 커피가 맛없어요.
# 2층 창가 바다뷰 좋고 아메리카노 2900원에 매우 저렴한데 맛도 나쁘지않아요 빽다방커피보다 맛있는정도 일찍오픈해서 좋고 음료도 다양해서 좋음
# 커피 맛있고 쿠키도 맛있습니다.
# 시원달달한 아이스티와 청귤에이드.오션뷰까지 받쳐주니 금상첨화.1층주문.  2층 시음.장타때리는 커플들만 없으면 더 좋을텐데
# 규모는 작지만 뷰가 옆건물 스타벅스보다 좋습니다. 스벅은 건물외장재가 뷰를 가려버려요.제주 로컬 브랜드 커피샵은 처음인데 가격저렴한 편이고 커피맛 나쁘지 않았습니다.
# 뷰 가성비 친절 깨끗합니다 음료는 무난합니다
# 함덕 카페중 가성비는 최고맛은.. 그냥 에이바웃...ㅋ 뷰는 좋음
# 뷰가 좋은 가성비 최고 카페
# 커피+디저트가 아주 좋네요. 뷰도 좋아요~
# 레몬에이드 맛이 그냥탄산수에 레모나넣은맛이네요..
# 오전할인도 있고 직원분도 친절하시고 좋아요
# 10월 21일 아침 7시에 근무하시던 함덕점 남자직원분(안경 쓰셨어요) 칭찬합니다!도민이라 도내 에이바우트 여러 지점을 가봤는데함덕점 남자직원분은 분위기가 밝고 말할 때마다 눈 마주치며 대해주셔서 에이바우트에 대한 이미지가 달라졌어요동네 지점 두고 경치보러 일부러 왔는데 먼거리 온 보람이 있네요ㅎㅎ일부러 칭찬글 남겨요참고로 커피맛과 화장실은 신경써 주시면 더 좋을것 같아요(별☆이 4개인 이유^^;;)
# 사람이 정말 많지만그것은 오래있을 수 있다는것...!뷰도 좋습니다
# 아침 11시전에 가기 좋음 조용함
# Amazing coffee and price and dessert.  Great customer service.
# 가격대 엄청 좋고 음료와 디저트도 좋고 컨센트도 좌석마다 있고, 넓고 시원하고 전망도 좋음. 핵심은 싸고 맛있는 음료임.
# 갈수록 디저트 종류가 없고 관리부실, 오후1시 한창 영업시간에 케잌이 냉동실있다고 먹으려면 10분기다리란다.첫번사진오늘오후 2021.05.26뒷사진 작년가을 초창기때 사진
# 모닝 아아(11시까지) 1800원 테이크아웃. 맛 좋아요! 바닷가 들고가서 먹었어요
# 에이바우트커피 처음 가봤는데요. 전 음료 주문하면 디저트도 같이 주고 디저트를 안먹으면 할인해준다는 사실을 몰랐습니다. 점원은 아무말도 안해줬구요.옆에 커피 시키면 디저트도 같이 준다고 써있길래 그런가보다 싶었고 아메리카노와 아이스바닐라라떼 두잔과 모찌롤을 함께 주셨길래 이게 그건가보다 하고 가져갔죠. 4층에 자리 잡아서 사진 찍고 먹으려는 찰나 직원이 와서 모찌롤 안시켰으니 가져가겠다고 하더니 모찌롤을 뺏어가더군요. 저는 모찌롤을 왜 가져가는지 영문도 모르고 디저트 주문 안했는데 가져간 사람이 된 것 같아 당황스러웠습니다.알고보니 할인을 해주긴 했더군요. 아메리카노 4900원 + 아이스바닐라라떼 5900원 = 10800원인데 6800원 결제되었습니다. 그런데 딱 50% 할인을 해준 것도 아닌데다가 주문할때 디저트 고르시겠어요 아니면 디저트 안시키고 할인받으시겠어요 라고 물어보지도 않고 맘대로 모찌롤 하나 올려놓고 나중에 와서 뺏어가는건 또 뭡니까 ?직원 교육 좀 제대로 합시다.
# 전 ㄷㅁㄷ 보다 좋았어요
# 여기는 다른 함덕카페에 비해 뷰가젛슺니다 높은층이있어소그런가
# 에이바우트 함덕,하귀,토평,스타디움 매우추천
# 맛보다는 가격이나 공간이 좋아서 에이바웃 자주 이용하는데요, 진짜 음악소리 너무 커요.... 이어폰껴도 이어폰 소리가 잘 안들릴정도ㅠ
# 11시전에 가면 1400원에 아메리카노를 대신 맛은 그냥 그렇다. 하지만 함덕뷰를 살 수 있다.
# 그런데 ᆢ허브티 하루종일 1500원 아닙니다 ~탁트인 뷰ᆢ무한대로 넓은 환경~마음놓고 쉴 수 있는 공간 구성 쾌적한 실내 장식 ᆢ허나4층은 한 팀만 떠들어 제껴도울림이 심해서 2층으로 피신왔네요~^^의자도푹신하고음료값도 저렴하고 맛도 좋구요자주 오려구요~~~^*^
# 언제나 무난히 괜찮은 맛이랑 환경 보장
# 직원분이 청소 열심히 하셔서 (물론 바쁜 시간엔 한계가 있지만) 대체적으로 깨끗합니다. 뷰 굉장히 좋습니다. 음악이 줄여달라고 하면 줄여주십니다.
# 4층 창 개방했는데 바다가 한눈에 보여서 이뻐요 ㅎㅎ
# 테이블 많음 그만큼 사람도 많음. 저렴함
# 선곡 너무 시끄럽고 노래 소리 너무 커서 일하기엔 그닥..
# no more reviews to load
# 2 . 파리바게뜨 함덕해수욕장점
# 너무 친절하고 매장 깨끗하고 빵이  너무 맛있어용.
# 빵 종류 많고 직원분들 친절쓰
# 친절하고 깔끔해요
# no more reviews to load
# 3 . 루스트플레이스 함덕해수욕장점
# 맛과 분위기 최고입니다.  한림도 루스트 있지만 함덕뷰 즐기며 돈까스 먹으려고 왔어요.가성비 갑^^ 뷰맛집이예요~^^와 보신 분들은 또 올거 같아요.  저도  재방문 당근당근입니당.😄
# 엘레베이터에서 부터 토냄새가 심각함.들어가자마자 음식물 쓰레기 냄새 심각함환기를 시키든가 .. 쓰레기를 잘 버려주세요 정말 최악의 루스트 ;;;;;;;;;;;;
# 갈때마다 청결도 좋지 않고 맛도 없어서 정말 어쩔수 없을때만 가는데요. 샐러드는 좀 심하네요. 저건 아주 오래된 샐러드네요. 노란 물까지 바닥에 뚝뚝. 괜히 비위만 상했어요. 청결 맛은 그렇다 쳐도 식재료 위생은 신경 부탁드려요.
# 그냥 삼분요리 수준인데...간단히 외식할때 가는 수준이에요...더이상 음식값도 저렴하지도 않고...특히나 함덕점은 직원들이 불친절하기까지 하네요다만 뷰만 좋네요
# 부모님 모시고 함덕왔다가, 원래 가려고 했던 식당이 휴무일이고.. 다른 가게는 전부 예약제여서 무난하다는 루스트로 옴.뷰…는 예쁜데 생~각보다 넓진 않고… 외도점이 더 맛있음.. 갑자기 급하게 식당변경하지 않았더라면…굳이굳이 오진 않았을 것 같음..
# 진짜 맛없어요......... 그냥.... 음..... 대학가에 가면 파는 저렴한 음식맛...가격은 싸니까...ㅎㅎㅎ.... 그냥 저렴한 패스트푸드급 레스토랑........ 여기 체인점인거 아시죠? 굳이 제주도까지와서 체인점 갈 이유가 있나 싶오요 ㅠ ㅎㅎㅎ 까르보나라가 이렇게 맛없다니.......ㅎㅎ 등갈비도 별로........ 그리고 다른데 잘못 먼저나가서 파스타 다먹고 받음 ^^... ㅋㅋㅋㅋㅋ뷰는 좋아요 그래서 2점ㅎㅎ 그리고 생맥한잔에 900원인가? 저렴함 ㅎㅎ...저는 운좋게 창가 앉았지만 창가 앉으려면 웨이팅 해야할수도 있어요 애매한 저녁시간에 갔는데 제뒤로 3~4팀 창가웨이팅함 그냥 맛 기대없이 뷰 보면서 배채우려면 가세요
# 제가 가본 루스트 매장 중 뷰가 가장 좋았어요 다만 제가 가본 루스트 매장 중 서빙하시는 직원분이 가장 적으셨어요이렇게 바쁜 시간대에 서빙하시는 분이 달랑 두분 이라니사장님~~장사 잘 되실텐데 직원 분 한 분 더 고용하시는게 어떠세요~? 너무 열심히 영혼 없이 일하셔서 괜히 나 학생때 아르바이트하던 생각나고 막 그랬네요가격은 혜자스로웠고 맛도 루스트 다웠습니다~~~!!!
# 저녁에 왔는데 창가자리는 없어서 안쪽에 유리부스좌석에서 먹었습니다. 바다는 안보이지만 가족끼리 넘 오붓하고 조용하게 먹었네요.알로고 세트에 샐러드 추가했는데 모든 음식이 맛있고 가성비도 참 좋네요. 가족끼리 오신분들 추천드려요
# 생각보다 가격저렴하고.맛나요
# 평점보고 걱정햇는데 걍 그럭저럭 맛은 갠츈합니다뷰도 좋고..청결관리만 좀 더 신경쓰시면 좋을듯요
# 인근 맛집엔 노키즈존에 아기의자 없어서 평점이 안 좋아도 그냥 왔어요~근데 이 가격에 이 정도 양/맛이면괜찮은 거 같아요 오히려 파스타 더 비싼 곳들도 맛 없는 곳 많은데저는 만족하면서 잘 먹었어요 ~~가격도 저렴한데 뷰도 넘 좋고 맛은 평균 ! 남편이랑 잘 먹구 갑니당☺️
# 해외에서 백신 2차 까지 맞고 왔는데 국제협약(?)이 안되서 백신패스가 적용이 안되어 가족 5명(성인2 소인3)을 입장 안된다는 가게입니다. 젊은 남자 점장과 통화한 본사에서도 해외서 맞은 백신이 적용이 안되어 보건소에서 서류를 띠어 와야 한다는 것도 이해가 안되네요. 어플로 해외서 맞은 것도 보여줬는데…전국에서 해외서 백신 맞은 한국인을 안받아준 곳은 이곳 밖에 없는거 같네요. 정확한 정보를 가지고 사업장을 운영하여야 겠습니다.
# 그 좋은 자리에서 왜 그렇게 장사하고 있는거죠? 본사의 관리가 시급해 보입니다. 안좋은 리뷰는 굳이 잘 안쓰는 편입니다만.. 모든면에서 심각하네요.
# 여지껏 갔던 루스트중 제일 별로임. 볶음밥이 아니라 그냥 소스에 비빈밥이었음.
# 배달로 튀김 시켰는데 딱봐도 시판인데 맛이 없는.. 새우는 엄청 작고 튀김옷만 큼.. 오징어링도 마찬가지.. 내용물이 갈은 오징어? 너무 맛없어서 다버림.. (집에서 시판제품 사서 에프 돌려도 저것보단 맛있겠더군요) 돈까스도 맛없는데 겨우 먹었어요. 차라리 김밥x국이 나을듯.. 입맛 고급인 분들은 안가시는게 정신건강에 이롭습니다.
# 혼자 방문했고, 창가 자리 치우고 있길래 앉아도 되냐고 물었는데 옆에 분이 대기중이라길래 알겠다하고 그냥 2인석에 혼자 앉아있는데 어떠한 응대도 없었음. 뒤이어 들어온 가족 고객분들에겐 바로 물과 메뉴판을 가져다줬지만 내겐 메뉴판은 커녕 아무것도 가져다줄 생각도 없는듯이 그냥 옆테이블 치우고 이미 식사중인 고객들 챙겨주기 바빴음. 한참 지나고 멀뚱히 앉아있으니 그제서야 메뉴판 드릴까요라고 묻는데 그럼 음식 먹으러왔는데 메뉴판을 줘야 고르죠. 그래서 가져다달랬는데 아무리 생각해도 기분이 더러워서 그냥 나왔음. 7월 초 방문했고 여행 다니는 내내 기분 좋았는데 여기 덕분에 아주 초쳤던 생각이 납니다 ㅎㅎ 남자분 두분이 계셨는데 사실 가게이름도 생각 안났지만 어찌저찌 찾아서 꼭 후기 남기려고 검색해봤고요. 거기 나온 덕분에 더 좋은 식당 찾아서 기분좋게 식사 끝냈네요. 여기서 안먹길 천만 다행으로 생각함
# Very poor and rude customer service.  I didn’t eat here. I got here and the staff that was working told me to get out rudely because I arrived earlier than lunch.  The food looked good, but I won’t come back because of the one guy.
# Очень жесткое мясо , соус не соответствует выборному .
# 위치는 함덕이 다 보이는 사이드쪽에가격은 미친 가격이고 맥주 맛도 좋아요.음식 맛은 중간 입니다. 가격 생각하면쏘쏘구요.
# 가성비가 넘치는 곳!!
# 여기 진짜최고ㅜㅜ왜 안유명한지 모르겠어요 음식들도 다 평타는 치고 무엇보다 테라생맥 900원+뷰맛집.. 화장실도 깔끔해요ㅠㅜㅜ 맥주좋아하시면 방문하는게 돈벌어가는거임ㅎ
# 관광지에 있는 지점이라 불친절하지 않을까 싶었는데엄청 친절해요! 음식도 맛있습니다
# 가격 합리적이고 맛있어요~ 그리고 엄청 친절해요!
# 저렴 존맛 로컬! 짱
# no more reviews to load
# 4 . 메가MGC커피 제주함덕해수욕장점
# 가성비 지렷다 위치도 바다 바로앞
# 3월 7일 오전에 아아 하나 테이크아웃 해서 먹었는데요!! 얼음도 많이 주시고... 부탁도 들어주시구... 덕분에 함덕해수욕장 구경 너무너무 잘했어요!! 정말정말 감사합니다또 가고싶어요!
# 1점도아깝다매장관리안되있고 음료도 다른지점보다 별로고 음료도 다흘려서주고 손닦을거달라해도 대답안함화장실어딨냐고해도 대답안함 이물질묻어있는 쓰던행주로 대충 닦아서줌믿고거른다
# 손님이 많은것 대비 일하는분이 한명이라 속도가 너무 늦어서 기다리는 시간이 길어요..
# 제가 죠리퐁라떼를 먹고 한번 씹고뱉은 벌레입니다. 매장에 들고 찾아가니 5만원줄테니 합의하자네요. 황당합니다. 발견한것도 아니고 씹고 뱉은건데 대처를 이런식으로 하다니요..? 매장도 많이 지저분해보이던데 이런식으로 비위생적으로 장사할꺼면 폐업을 하세요.
# 불친절. 매장청소관리안됨.
# 싸고 양많아서 좋음
# 불친절을 떠나 음료 얼음 진짜 대충 갈아주시네요 조리퐁라떼 시켜먹었는데 우유를 아끼는건지 뭔지 조리퐁하고 얼음만 잔뜩넣고 대충 갈아서 빨리지도 않고 화딱지나서 와 진짜
# 와 진짜 열받네. 스무디 시켜서 차에 타서 가는중 먹으려고 빨대를 빠는데 안 빨려서 보니 얼음이 얼마나 큰지 구멍이 막혀서 안 빨리네.얼음을 대충 갈아서 전체적으로 알갱이가 커서 얼음만 씹다 다시가서 얼굴에 뿌려버릴려고 했는데 집사람 말려서 억지로 참음. 스무디는 그냥 버림.개 빷는 곳.다른곳도 자주 이용해 봤지만 이렇게 일 못하는 사람 처음 봄.
# 카라멜 마끼이또  원래 이리 나오나요?위에 뭐 올려있고 카라멜시럽도 있지않는지요간만에 마시는데  그전과 아주 크게 차이가 납니다그냥 믹스커피 먹는맛보다 아닌듯 해요아~~한모금 마시고 깜놀 했습니다.실수 하신건지?원래 이리 나오는건지?아
# ☆불친절한걸로는 리뷰를 남기지 않는 편입니다!!☆알바가 진짜 싸가지가 없어요..이거 있나요 저거 있나요 물어봐도 없다고만 합니다.없으면 없다고 해야하는게 맞죠.근데 어떠한 이유로 없는지 말해주는게 기본 아닌가요?시즌 아웃이면 시즌 아웃이다, 재고가 없으면 없다.근데 말투부터가 '없으니 꺼지세요~ ' 이따위로 말을 해요!표정도 굉장히 찡그리면서 오더를 받아요!!제가 띠껍게 물어보지도 않았는데,제 일행이 듣다가 화나서 발끈 할 정도였어요!관광객 대상 매장이라서 그런지,직원이나 사장이나 서비스 정신이 하나도 없어요!매장도 굉장히 지저분하고!(카페인데 테이블에 기름기, 구석에 먼지뭉텅이)음료 맛도 별로에요..(얼음 제대로 안갈림, 설탕 시럽만 엄청 넣음)큰거 바라는것도 아니에요.. 보통이면 되는데...커피 마시러갔다가 홧병만 얻고 왔어요!!본인이 버러지 취급을 받고싶거나,서비스 태도에 예민하지 않는분만 가는걸 추천드려요!
# 진짜 싸가지 ♩♬♬게 없네요 리뷰보고 아무리 싸가지 없다고 해도 그래봐야 얼마나 하겠어 생각하고 평소 좀 싸가지없는 알바생들봐도 지들도 힘드니까 그렇겠지하고 이해하는편인데 여기알바는 진짜 역대급이네요 여자만아니였음 진짜 한대쳐갈기고싶네요
# 제일중요한커피맛이...
# 정말 어지간해서는 후기 안쓰는데 직원들 위생관념이 정말 없어요. 외출했다온 직원 그냥 조리, 얼음 담는직원 컵에 얼음 잔뜩 담고 흘러 손에 뭍어 다시 얼음통으로  들어가고, 제빙기에서 얼음 담아오는 스텐볼을 그냥 다시 제빙기에 넣고....하 참 바쁜건 알겠는데 너무들해요. 직접 보고 아이스아메리카노 받아오는데 엄청 찝찝...거 점주님 위생에 신경좀 씁시다.
# 직원도 많은데 커피홀더는 왜 손님들한테 챙기라하는지. 직원분들 놀고 계시던데요... 그리고 불친절해요
# 별 한개도 아까운 불친절한 직원. 기본적인 예의도 없음
# 동네주민이라 거의 매일 가는데 이렇게 불친절한 직원은 처음 봄ㅋㅋㅋㅋㅋㅋㅋ
# 음료는 괜찮았는데 점원이 너무 불친절하시네요화장실 위치 적혀져있었어도 잘 못봐서 물어봣더니 목소리도 넘 작으시고 신경질적이시고 말이 너무 빠르시구 물론 미소같은건 없으시고ㅎㅎ 어무니한테도 똑같이 대하셔서 좀 짜증났네요 진짜 ㅡㅡ
# no more reviews to load
# 5 . 이디야커피 제주함덕해수욕장점
# 사람없고 조용해서 좋지만 그만큼 대화소리 다들려서 민망해요 테이블과의 거리도 가까운편임
# 직원이 친절하고 커피도 맛나요
# no review in crawling
# no more reviews to load
# not found
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# 함덕해수욕장_reviews.csv saved.
# finish

# %%
import os
from time import sleep
import pandas as pd

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')
chromedriver_path = "C:/chromedriver"
driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)

def search(place):
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')
    search_area.send_keys(place)
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)
    sleep(1)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem')

    crawling(place, place_lists[:5])
    search_area.clear()

    try:
        driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
        sleep(1)

        for i in range(2, 6):
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
            sleep(1)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            place_lists = soup.select('.placelist > .PlaceItem')

            crawling(place, place_lists[:5])

    except ElementNotInteractableException:
        print('not found')
    finally:
        search_area.clear()

def crawling(place, place_lists):
    global driver, all_data

    for i, place in enumerate(place_lists):
        place_name = place.select('.head_item > .tit_name > .link_name')[0].text

        detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
        driver.find_element_by_xpath(detail_page_xpath).send_keys(Keys.ENTER)
        driver.switch_to.window(driver.window_handles[-1])
        sleep(1)

        print(i+1, '.', place_name)        
        
        data_dict = extract_data()

        if data_dict:
            all_data.append(data_dict)

        driver.close()
        driver.switch_to.window(driver.window_handles[0])

def find_element(xpath):
    global driver

    try:
        element = driver.find_element_by_xpath(xpath)
        return element.text
    except NoSuchElementException:
        return ""

def extract_data():
    global driver

    place_name = find_element('//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/h2')
    place_location = find_element('//*[@id="mArticle"]/div[1]/div[2]/div[1]/div/span[1]')
    place_feature = find_element('//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/span[1]')
    place_star =  find_element('//*[@id="mArticle"]/div[5]/div[1]/div/em')
    operating_time = find_element('//*[@id="mArticle"]/div[1]/div[2]/div[2]/div/div[1]/ul/li/span/span[1]')

    crawling_data = [place_name, place_location, place_feature, place_star, operating_time]
    
    if place_name:
        data_dict = {"place_name": place_name,
            "place_location": place_location,
            "place_feature": place_feature,
            "place_star": place_star,
            "operating_time": operating_time}
        return data_dict, print(crawling_data)
    else:
        return None

def main():
    global driver, all_data
    all_data = []
    driver.implicitly_wait(1)
    driver.get('https://map.kakao.com/')
    
    place_infos = [input("")]
    place_infos_str = "".join(place_infos)

    for i, place in enumerate(place_infos):
        if i % 4 == 0 and i != 0:
            sleep(1)
        search(place)

    driver.quit()
    print("finish")

    # Save all_data to a CSV file
    if all_data:
        data_frame = pd.DataFrame(all_data)
        data_frame.to_csv(f"{place_infos_str}_reviews.csv", index=False, encoding='utf-8-sig')
        print("Data saved to top_25_places_data.csv")
    else:
        print("No data to save")

if __name__ == "__main__":
    main()

# %% [markdown]
# # 전체 크롤링 코드

# %%
import os
import csv
from time import sleep

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

##############################################################  ############
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')
chromedriver_path = "C:/chromedriver"
driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기

reviews = []  # 중복 리뷰를 저장하지 않기 위한 리스트 생성

def main():
    global driver, load_wb, review_num

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

    # 검색할 목록
    place_infos = [input("")]

    for i, place in enumerate(place_infos):
        # delay
        if i % 4 == 0 and i != 0:
            sleep(5)
        print("#####", i)
        search(place)
        
    # 저장된 리뷰를 CSV 파일에 저장
    save_to_csv(place, reviews)
        
    driver.quit()
    print("finish")

def search(place):
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem') # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, place_lists)
    search_area.clear()

    # 우선 더보기 클릭해서 2페이지
    try:
        driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
        sleep(1)

        # 2~ 5페이지 읽기
        for i in range(2, 6):
            # 페이지 넘기기
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
            sleep(1)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            place_lists = soup.select('.placelist > .PlaceItem') # 장소 목록 list

            crawling(place, place_lists[:5])

    except ElementNotInteractableException:
        print('not found')
    finally:
        search_area.clear()

def save_to_csv(place, reviews):
    file_name = f"{place}_reviews.csv"
    with open(file_name, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['review']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for review in reviews:
            writer.writerow({'review': review})
            print(f"{file_name} saved.")


def crawling(place, place_lists):

    while_flag = False
    for i, place in enumerate(place_lists):
        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address

        detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
        driver.find_element_by_xpath(detail_page_xpath).send_keys(Keys.ENTER)
        driver.switch_to.window(driver.window_handles[-1])  # 상세정보 탭으로 변환
        sleep(1)

        print(i+1,'.', place_name)

        # 첫 페이지
        extract_review(place_name)

        # 2-5 페이지
        idx = 3
        try:
            page_num = len(driver.find_elements_by_class_name('link_page')) # 페이지 수 찾기
            for i in range(page_num-1):
                # css selector를 이용해 리뷰 페이지 찾기
                driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name)
                idx += 1
            driver.find_element_by_link_text('후기 더보기').send_keys(Keys.ENTER) # 버튼 누르기
            sleep(1)
            extract_review(place_name) # 리뷰 추출
        except (NoSuchElementException, ElementNotInteractableException):
            print("no review in crawling")

        # 그 이후 페이지
        crawl_next_reviews(place_name)

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환

def extract_review(place_name):
    global driver, reviews # reviews 리스트를 사용하기 위해 global로 선언
    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 현재 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')

    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        for i, review in enumerate(review_lists):
            comment = review.select('.txt_comment > span')  # 리뷰
            if comment:
                comment_text = comment[0].text.strip()  # 공백 제거
                if comment_text and comment_text not in reviews:  # comment_text가 비어있지 않고 중복이 아닌 경우에만 출력
                    reviews.append(comment_text)  # 중복이 아닌 리뷰를 reviews 리스트에 추가
                    print(comment_text)
    else:
        print('no review in extract')
        ret = False

    return ret

def crawl_next_reviews(place_name):
    global driver
    max_clicks = 5  # 최대 클릭 횟수 설정
    click_count = 0 # 현재 클릭 횟수 초기화
    while click_count < max_clicks:
        try:
            driver.find_element_by_link_text('후기 더보기').send_keys(Keys.ENTER)  # 후기 더보기 버튼 클릭
            sleep(1)
            if not extract_review(place_name):  # 리뷰 추출
                break
            click_count += 1  # 클릭 횟수 증가

        except (NoSuchElementException, ElementNotInteractableException):
            print("no more reviews to load")
            break

            
            
if __name__ == "__main__":
    main()
# Out:
#  제주도 해수욕장
# ##### 0
# 1 . 이호테우해수욕장
# 말 필요 없음
# 이호테우 해변 비오는 날 방문했는데 운치있고 넘 좋네요!!!!
# 좋았어요 ㅎㅎ 말등대도보공
# 귀여운 말등대가 있는 해수욕장🪅아이들 놀기 좋은 해수풀장이 있어요~
# 제주도 마지막 여행지
# 그냥 시원한 맛에 갈만함 사람 꽤 있는 편이고 말 등대까지 산책하기 괜찮음 -겨울방문- 여름에는 해수욕 하기 괜찮을듯 잔잔하니 아이들이 놀기 괜찮음
# https://youtu.be/R4hXLXd9s9Aok차박 이호태우해수욕장 유튜브 검색하시면 동영상 올렸습니다 낮과밤 차박지
# 꼭 건강 해져서 다시한번 가고싶다 병원 밖으로 나가서  제주도로 가자
# 서핑스팟으로서0점. 라인업에 사람 30명중문처럼 꼽주는 쓰레기 다수물론 좋은사람이 많지만까맣고 얼굴 찌뿌리고 있는 사람 많은 해수욕장에는서핑하러 가는거 아님
# 물이 맑아서 속이 다 보이는 곳!말 동상으로 유명해서 와보고 싶었던 곳!!플라스틱에 대한 경각심을 불러일으키는 곳!
# 인생샷 찍으러왔니? 응 여기아니야..처음가봤는데 말등대가 왜이리 멀어.. 이호항 으로 가야댐 가즈아!
# 제주도 바다 중 물색은 가장 안 좋은듯...
# 알바생들이 손님 뒷담까면서 욕하네요^^ 담부터는 안갈듯요~ 흔한 일진알바생인지  불쾌하네용^^
# 좋았음
# 제주바다중에 가장더러운 해수욕장?  절대 가지마시길 가실거면  협재  김녕 함덕 표선이  제일  좋고 깨끗함
# 좀 걷긴 해야하지만 버스 정류장이 근처에 있어서 접근성이 좋았어요 하지만 물이 좀 더럽고(해조류 많음!) 화장실에 냄새가 났어요 ㅜㅜ 그래두 가볍게 물놀이 하기엔 좋아용!!
# 예쁜 뷰가 보이는 항구...
# 물더러움 냄새남애기들은 이호테우 해수풀장에서 노세용
# 관리가 제대로 안되고 있는 거 같아요;; 서핑하러 갔다가 물이 더러워서 한시간 만에 나왔어요물에 비닐봉지도 너무 많이 떠다녀서 충격먹고 나왔습니다....
# 애랑 가서 놀기좋아요 물이 깨끗하진 않고 바닥에 바위 뾰족한게 있어서 물놀이시 조심해야 합니다 공항근처라 바다에서 지나가는 비행기 구경도 재밌어요
# 바람과 함께하는 해수욕
# 이호테우는 말이 필요없는 곳공항근처,도심 근처라서 접근성 말이 필요없고물도 깨끗 맑고 이쁨 단점은 해변뒤로 비행기가 착륙해서 조용하지는 않음……
# 날씨만 좀 더 좋았으면 더 예뻤을것 같아요!! 말등대 특이해요 ㅎㅎ
# I found this by accident driving around. Perfect evening in June. Beautiful place to sit and enjoy watching people enjoying life together. One of the best beaches I've seen on Jeju.
# 2 . 남원큰엉해변
# 한반도 지형, 생각했던 것 보다 훨씬 아름다웠다.사진찍는 건 좋은데, 기다리는 사람이 많을테니 다음 사람을 위해서 눈치껏 찍고 빠져야 욕을 안 먹는다.
# 산책하기 너무 좋아요!
# 기대안하고갔는데 바다가 보이는 산책코스로 정말 좋았어요
# 정말 예쁜 올레길
# 한반도 지형 보러오세요주차는 금호리조트에^^
# 금호리조트 씨유 옆 주차 후 내려가면 금방 나옴한반도 지형 표지판 발견 후 뒤돌면 돼요ㅎㅎ해안가 산책로가 잘 되어 있음아늑하고 너무 좋음
# 한반도 모양 찍으러 갔는데 잘 안 보임
# 평범한 해안입니다 안가셔도 될듯
# https://youtu.be/Ebyha454GcMok차박 큰엉유튜브 검색하시면 동영상 올렸습니다 큰엉부터 한반도나무 쇠빠진고망 인디안추장얼굴 호두암 유두암
# 호두암 유두암 보면 볼것 끝이니 되돌아가세요
# 한반도는 들어가서 오른쪽 입니다. (서쪽)인디언 바위 주변에 있어요.🙂
# 큰엉해안경승지. 산책로를 걷다 보면 길 양옆 나무 사이로 한반도 형상 나타남. 20m 가까이 되는 해암 기암절벽 이어짐
# 뷰가 좋다
# 지나가다가 우연히 들린 곳인데 너무 멋졌습니다바다와 절벽만 보고 숲은 모르고 지나쳐왔네요다음에 다시 가보고싶습니다아! 절벽 사이사이 잘 보시면 고양이 있어요 야옹
# 20220602
# 저희도 반대로 왔음 ㅋㅋㅋㅋㅋ 아침일찍가야해요
# 꼭 아침일찍가야 사람도 없고 마음껏 찍을 수있어요그리고 한반도 모양 반대쪽으로 걸어오시는분들은 한반도모양 모르고 가시는분들 많더라고요아쉬울따름
# 산책하기 좋고 풍경 멋있어요! 그리고 주차장 근처 무인 귤가게에서 파는 한라봉+천혜향이 꿀맛이에요..
# 사진 잘나오고 이뻐요풀냄새도 좋고 바닷바람도 좋습니다
# 한반도 모양의 사진은 워낙 유명하고 그 이외에 핫한 동굴샷 찍으려고 암벽등반하고 옴.ㅋㅋㅋ
# 해안산책길도 좋고 한반도 형상도 신기했어요ㅎㅎ 한반도 형상은 남원큰엉해변 찍고 가서 왼쪽길로 가야 있습니다...
# 풍경이 사진에 안담겨 아쉬울 뿐입니다. 너무 산책하기 좋은 코스.. 노을이 쥐김
# 풍경 멋지고 산책로도 좋아요
# 3 . 함덕해수욕장
# no review in extract
# 함덕 가신다면 스타벅스보다 해수욕장 바로 앞에 있는 카페 가길 추천 드러요 뷰가 좋거든여   맛보장은 못드려요
# 따로 찾아서 올만한 곳 입니다.바닷가랑 가까운 곳에 주차장도 별도로 있구요.
# 서쪽에 협재해수욕장 이라면 동쪽으로는 함덕인듯. .너무 멋지고 바다 가운데 섬처럼 썰물때는 드러나는 모래섬으로 산책도 할수있고 조성도 잘되어 있고 주변 상권도 잘조성되어 있다...깨끗하고 예쁘다...막상 산책다니고 4일을 머물렀는데 해변사진은 몇장없네...다시 찾게될 바다~
# 나들이
# 체고 ,,
# 제주에서 제일 이쁜 바다뷰에 주차까지 좋았음.
# 바다빛깔 넘 예뻤어요 🫰
# 예뻐요
# 이쁨
# 내가 너무나 애정하는 해수욕장❣️바다색도 최고 예쁘고, 사부작 사부작 거닐며 산책하기에도 좋은 곳 :)
# 행복했다 ‼️
# 1년한번가는 제주도  헤헤  또가고싶다
# 여수보다 다시 찾고 싶은 밤 바다
# 바다도 하늘도 미쳤다
# 아주 좋아요 가을에가도 물놀이 물놀이 물놀이 할 수 있어요
# https://youtu.be/egjck4nZ4w0ok차박 함덕해수욕장 유튜브 검색하시면 동영상 올렸습니다 여러편과. 아름다운해변 드론영상도 있습니다
# 아름다운 에메랄드 빛 바다색. ^^
# 이게 제주 바다다!!!
# 함덕해변 너무 예뻐요... 흐려도 새벽에도 저녁에도 언제나 아릅답네요 처음 와봤는데 베스트가 될것 같습니다
# 그립다아
# 해물이 신선하고 조개살이 신선해서 달고 맛있어요 주아주머니 도 친절하셔요
# 올레길 19코스를 역으로 걸으면 이 해변의 아름다움을 찬란하게 맞이할 수 있다.
# 2022.08. 바닷가와 주변상가가 거의 붙어 있는 곳. 숙소만 잘 해결하면, 먹고 쉬고 놀기 좋은 위치.
# 옆 김녕바다 텃세에 제대로 실망해서 여기왔는데 여긴 그나마 괜찮네요
# 제주 바다는 밀물때 오면 좋아요~ 쌀물과 밀물의 차이가 엄청큽니다.
# 4 . 협재해수욕장
# 협재해변옆에 있는 야자숲거리(?)도 꼭 가세요ㅠㅠ
# 몇 번을 가도 또 가고 싶은 곳
# 주차공간도 많고, 사람도 많고사진 찍을 곳도 많고 넘 힐링되고 좋았어요화장실이 아주아주 멀다는 것과 바람이 엄청 불어 미친듯이 춥다는 것만 빼면제주 여행에서 가장 만족한 곳이에요•사실 선셋을 보러 간거지만,날이 흐려 아무것도 보지 못했구 밀물로 인해 돌들이 물에 잠기는 걸 보니여러 생각이 들었어요•제주 서쪽의 필수 여행지 다운것 같아요
# 물이 맑고 좋음
# 아름다운 바다♡
# 예쁜 풍경으로 아팠던 마음을 치유해줬던 곳이에요. 하루 종일 앉아있던 내게 아무 말 없이 토닥여준 고마운 곳.
# 외 이 렇 게 예 뻐 ?
# 사진은 부실하긴하지만협재해수욕장 괜찮습니다재방문 의사 강력하고 아마 제주 서쪽으로 여행갈때 또 방문하지 싶습니다.
# https://youtu.be/yua6wFfGU1Aok차박 협재해수욕장 유튜브 검색하시면 동영상 올렸습니다 비양도가 코앞에 그림 하얀바다 청량바다 차박은 곤란 바로옆 노외주차장 이용말이 필요없음 너무좋다
# 나쁘지 않았어요. 적당히 무난한 해변입니다. 제주도 아니어도 흔한, 적당한 해변 느낌...
# 제주 바다 말해 모해
# 에메랄드 바다 여유
# 어머 ~ 석양이 진다~
# 날씨가 너무 좋아서 모든게 좋았어요..
# 뭐 다들 아실테지만...
# 아주 오래전 기억에 있던 넓게 펼쳐진 아름다운 에메랄드 빛깔의 얕은 바다를 생각하고 갔는데, 멋진 뷰는 해변에 세워진 커피숍이 다 차지하고 있었고, 해안은 윈드서퍼 강습으로 북적북적.. 판자 타는걸 왜 그리들 즐기시는지...다른 나라의 아름다운 그리고 한적한 해변이 우리나라에도 하나쯤 있어야 할텐데..협재가 내 기억엔 그런 곳이었는데.이제 다시 가지 않을 듯..
# 아름다운 바다+비수기에도 넘치는 인파
# 물놀이하긴 좋으나 바로앞 파라솔이 날에 따라 시간에 따라 사람에 따라 가격이 천차만별 ㅋㅋ 언제는 만원이다가 처음 온 관광객 느낌 들면 이만 오천원까지 오르는 기적. 현금이나 계좌이체만 받는 뻔뻔함까지. 좋은 장소를 이런 분들 때문에 망치는듯장소는 좋으나 씨유파라솔 발려주는 거기는 가지마세요
# ,카페 루프탑에서 찍은 협재해변~ 맑고 청량하다 여기오기전 삼척 장호해변에 갔다왔는데 거기보다도 더 맑더라^^
# 제주에서 제일 예쁜 바다입니다!
# 물도 깨끗하고 너무 좋음물이 얕아서 가족 단위로 많이 오고 애들 놀기에도 딱 좋음
# 제가 가본 바다 중 가장 예뻐요
# 너무예뻐요 해수욕하기 좋네요
# 8월29일에도 해수욕하는 사람 많은곳. 동해바다에서는 볼 수 없는 광경. 물에 발 담그니 미지근하이 괘안타.
# 전에 한번 방문하고 기억에 남아 다시 재 방문 했습니다.해안도로 타고 많은 해변가를 가 봤지만 협제가 가장 관경이 좋습니다.다만 놀기엔 좀 좁을 수 있습니다. 중문 색달해변이 더 나을 수 있을 것 같습니다.
# 5 . 용머리해안
# 여기좋음 볼만한곳ㅎㅎ
# 관람시간은 매일 변경. 확인후 스케줄 잡으시고오늘 가 본 봐로는 일방통행으로 바뀌였습니다여전히 좋습니다
# 최고  사진 이쁘고 좀 위험해보이지만 멋쟈요
# 진정한 제주스러운 자연을 볼 수 있는곳매일 달라지는 입장시간 확인은 필수그리고 유채꽃시즌이라 그런지 2월평일인데도 차세울곳이 없어서 산방산보문사 밑 사설유료주차장(1일 2천원)에 겨우 세웠네요
# amazing
# 정말 멋진 곳이에요. 날씨 좋은 날만 갈수 있고 마지막 입장 시간도 매일 다르게 정해져 있으니 꼭 확인해보고 가세요
# 날씨 좋을 때 꼭 가보세요!!
# 미리전화해서열리는시간확인꼭해요관광갔다가 중간중간 할망들파는 해산물먹어요돌멍게껍데기에 소주따라먹어요하지만 적당히먹어요 돌밭이라 위험해요
# 날씨 좋울 때 다녀와서 너무 좋었어요
# 혼자 오시는 것 보다 둘 이상오는 것을 추천해요. 날씨가 안좋은 날에는 굳이 안가셔도 될 것 같아요. 세상에 혼자 남겨진 기분을 받고싶으시면 추천합니다.
# 이번 제주 여행에서 최애 장소.절경 그 자체!
# 무조건추천!뷰도좋고 인생샷 많이 건질수있음
# 용머리해안 사람 많음지금은 못들어간다고 하는데 사람 많았었음뒤쪽 산방산도 예쁨
# 하멜상선 전시관이 철거로 2022년 11월 21일 ~ 12월 31일까지 용머리해안 출입 금지랍니다 제주까지 와서 여길 못보고 가다니, 한라산 다음으로 보기 어려운 곳이네요, 날씨 좋은날 물때 맞춰 오지 않으면 출입금지, 이번엔 공사로 또 출입금지
# 필수코스로 추천!너무 좋았음.근데 사진으로 보는게 더 이쁨.
# 제주도에 온다면... 서귀포시에 온다면...꼭 들러야 할곳인것 같아요..!!너무 좋네요....하멜가념관도 있고.^^
# https://youtu.be/-_4omW-9AJsok차박 용머리해안 유튜브 검색하시면 동영상 올렸습니다 김암절벽과 절경물때 맞추면 갈수있는곳
# 정부야 환경문제에 관심좀 가져라
# 제주도 가면 여긴 무조건 방문해야됨너무멋짐 ㅠㅠ 뒤에 산방산 뷰도 넘멋짐가면갈수록 멋지니 꼭 끝까지 다봐야됨
# 멋지네요 ㅎㅎ2월에 실패했는데 오늘은 성공했어요생각보다 좋아서 놀랐네요여긴 ㄹㅇ 실패할수가 없는곳이에요자연경치 여기도 별로다? 그냥 제주도 오지마세요
# 어른은 입장료 2천원아이들과 함께 멋진 뷰를 볼 수 있어 너무 좋았어요9:00-3:30까지 관람 가능하고 날씨가 안좋은 날은 관람이 어렵다고 하니 참고하시면 좋을 거 같아요부모님도 아이들도 모두 만족했어요비싼 관람료내고 대부분 관광지 많이 구경 다녔는데 여기는 입장료도 저렴하고 포토 스팟도 많아 좋았어요
# 정말 멋지다! 친구들과 여행에 내가 추천했는데 다행히 입장할 수 있었고. 생각보다 코스가 길어서 더 좋았다. 여긴 또 가고싶다.
# 산방연대 간 김에 용머리해안까지 봐줘야 만족스러움! 너 무 예 쁨!!!!!
# 멋진 사진을 찍을 수 있는 곳!
# 파고가 높아서 종일 통제에 걸림. 1차실패ㅠㅠ (진짜 파도가 잘못하면 죽을거같이 보이긴 하더라;;;) 담엔 꼭 관람 성공할거에요.
# 제주여행에서 제일 기억 남는곳이네요...인생샷 많이 찍었어요. 꼭! 끝까지 가세요 출구있어요. 초입보다 뒤쪽이 더 멋있습니다. 할머니들이 파시는 해산물은 맛은 봤지만 솔직히 바가지인거 같아요.
# 1 . 황우지해안
# 황우지해안의 선녀탕 물 색깔 진짜 장관입니다
# 맑은 날 가면 좋아요! ㅎㅎ
# 22.09.16 pm01:24 현 상황 아래로 내려가면 계단유실 근처도 못가게 되있어요도로쪽에서는 계단유실 표기 하나없고주차비는 무조건 받으시네요..
# 돌이 울퉁불퉁 미끄러워서 꼭 좋은신발 신고 가시구요(안미끄러운거) 내려가면 구명조끼 물안경 같은거 전부 대여할수 있는곳이 있급니다 3~4m정도로 은근 깊어서 스노쿨링하기 좋았어요 숭어나 전어같은 물고기도 있었습니다 계단 경사가 가팔라서 내려가기/올라가기가 빡센데 할만은 해요
# 내려갈수는 없는데 산책로따라보면 진짜 예쁨
# 힘든 물놀이 외   경치구경 하실분은 다른곳을 가시는걸 추천드려요~ 구경 하러 갔다가 사람들 올라오는거 보고 다시 돌아왔네요엄청 힘들어 하심,
# 물고기보다 사람이 많아요해안까지 접근하는 길 계단이 높아서 운동부족인 저는 힘들었어요
# 다이빙 포인트
# 빨리 여름되서 수영하고픈 곳이네요.  8월에 또 와야지
# 구명조끼가 있으면 좋아요. ^^ 즐겁게 수영하세요.
# 수영하러 가실거면 가시고 구경하실거면 가면 안되는 곳
# 최고에요!
# 바다멍때리기 짱
# 처음 가봤는데 제가 간날은 파도가 엄청 쎈 날이었고 키즈존이라는 것도 이해가 안 갈정도로 너무너무 무서운 파도였습니다. 아이들은 어떻게 노는 건지 대단해 보였어요 엉덩이와 다리에 멍이 엄청 생겼어요. 친구에게 들으니 제가 갔던 다음날부터 파도가 너무 쎄서 입장을 막았다고 하더라구요 ㅠㅠ날씨 좋은날 다시(?) 가보게 될런지 잘 모르겠어요 무서워서.........물반 사람반 아니고 파도반 사람반 !
# 너무 예뻐요
# 가족단위이자 무한키즈존의 목욕탕
# 선녀탕 짱..b
# 쩜
# 선녀탕 최고최고 무쟈게 이쁘네요
# 전복죽이 맛있고그안에 있는 전복이 살아있네요
# 물 색깔이 예쁘고 좋은데..날씨 안좋을땐 가지마세요ㅠ 날씨 좋을때 저도 다시 가렵니다,,,
# 경치는 말로표현 못하쥬...직접 보시는길이 쵝오!!!!!
# 8/23일부터 출입 금지 되었더라구요ㅜ
# 사람탕 리뷰 ㅇㅈ 사람진짜많아요근데 물맑고 이쁩니다 단점: 계단이 85계단ㄴ데 계단이 생각보다 높고 가파라서 어르신들 무릎관절 걱정되는 계단이엥ㅎ
# 최고!! 날씨가 신의 한 수~~ 넘 더워서 10분만에 12동굴 전망대, 선녀탕전망대만 쓱 보고 사진 찍고 왔는데 만족:) 관광 20분 컷인데 주차장 무조건 2천원 너무 해서 다른 갓길에 주차함ㅎㅎ 선녀탕에 지금 사람 출입 금지라 가까이에서는 못 보지만 풍경은 더 이쁘네요ㅎㅎㅎ
# 역시 아름다운 제주 의 바다 풍광을 느낄 수 있는 곳 입니다 시간대 잘 맞추어 가면 프라이빗 하게, 물놀이가능(구명쪼끼 착용하면 안전)
# 2 . 삼양해수욕장
# 특이하게 검은 모래해변~ 번잡하지 않아 좋다
# 검은 모래가 특이하다. 하지만 모래에 쓰레기, 스티로폼 조각이 많이 섞여있어 아쉽다.
# https://youtu.be/WC1kWTrmOJEok차박 삼양해수욕장 검색하시면 동영상 올렸습니다 경치좋은 풍경의 차박지
# 검은모래 해변 함덕 많아서 간곳 샤워탈의 2500원밖에 안하고찬물이지만 사물함이 비번
# 검은 고운 모레 해변 사람도 많지않아 좋았다
# 삼양라면이 생각남ㅋㅋ
# 해변이 검은색 모래인게 진짜 신기함…그거때문에 물이 맑아보이진 않음 주변으론 아파트뿐이라 식당카페가 많지는 않음그리고 해변이 공사하고있던게 아쉬웠음ㅠ
# 아무것도 없을것같아 기대안했는데 해지는 노을이 넘 이뻐요ㅠㅠ
# 제주 삼양해수욕장 ★★★★☆ 넓은 해변과 서핑가능한 파도 센 바다넓은 해변인데도 수영가능한 금줄 쳐진 곳은 너무 좁고 옆에 금줄 안된 곳은 서퍼들이 다 차지했다. 중간은 낚시꾼들 있어서 위험했다.. 아놔 대체 왜...아예 오른쪽은 금줄 없어서 스노클링 가능할 듯 하긴 했다.해변이 엄청 넓어서 물놀이는 괜찮은데 스노클링은 부적합해 보였다.맨 안쪽 수영 안전줄 영역이 좁다. 나머지는 몽땅 서퍼들 영역이다.서핑 관련 대여 사업때문에 동네에서 정한 구획 같았다.중간 해변에 바위가 많아 물고기가 많을 것 같은데 낚시꾼들때문에 스노클링은 포기했다.오른쪽 끝 작은 해변에 사람들이 물놀이 약간 하고 있었다.해변은 본중 가장 넓은데 중간에 낚시꾼 없으면 스노클링도 가능할 것 같긴 한데 아쉬웠다.
# 아름다운 해변, 애정하는 곳
# 노을도 예쁘고 다 좋지만 뒷처리가 정말 힘들어요...검고 고운 모래가 모든 곳에 붙어서 떨어지지 않는....
# 작은 해수욕장. 해안선을 따라가다보면 아무도 없는 스팟도 있다.검은 모래의 삼양과 흰 모래의 김녕 해수욕장을 비교해봐도 좋겠다
# 제주여행와서 잠시들린 곳인데 최고예요 ㅎㅎ
# 리뷰 쓰신분들 복 받으세요! 말 그대롭니다! 작지만 조용하고 정돈된 느낌의 해변입니다 석양 무렵 최고였어요
# 작지만 사람 없고 너어무 아름답습니다,,,
# 검은 모래라선지 노을질 때 색감이 완전 맛집니다
# 너무 예뻐요바다도 예쁘고 모래도 부드럽고
# 물빠졌을때 모래 물결모양이 너무 예뻐요 물이 진짜 투명함 꼭가보세요 이상하게 여운남는곳
# 검은모래사장
# 검은 모래가 신비롭게 느껴지는 바다에요 이뻐요
# 담달에 갑니다 ㅋㅋ
# 일몰사진 찍기 좋아요
# 기대 1도 안 하고 갔는데 일몰이 너무 예뻐서 감동 받음
# 3 . 행원해변
# 뭐 그닥...풍력발전기들이 옆에 있어서 미래소년 코난에서 이름을 빌렸나?
# 행원에서 나고 자랐는데 코난해변라는게 웃기다ㅋㅋㅋㅋ 이름이 딱히 있진 않았었지만 이름이 지어져도 행원해변이라 하면되지 무슨 코ㅋ난ㅋ 어이없다하하핳하하하
# 코난 해변. ㅋㅋㅋ본래 이름은 세화해수욕장. 비석까지 있었음. 눈으로 보기에는 정말정말 기가막히게 편안하고 아름다운곳이 분명합니다.저도 가끔 가지만, 물에는 안들어갑니다. 마지막으로 들어간게 2008년이었습니다. 그 이후에들어가도 발만 담궈요. 생각보다 물이 더러워요. 못가게 하는게 아니라 진심으로 말씀드립니다.입구 옆 도로 밑으로 나오는 하천물(인근이 밭 천지라 액비와 농약사용이 빈번한곳)과 바로옆 양식장에서 물을 버리면 코난해변으로 옵니다. 양식장 물은 유난히 더 비린데, 사료와 항생재, 생선 배설물이 뒤섞여 있는 바닷물을 배출하는곳입니다. 그래서 코난해변 물은 각종 벌레가 많고, 돌에 끼어있는 이끼들도 지저분 합니다. 자세히 봐보세요. 모래속에서 애벌레가 꿈틀거립니다.
# 진실은 언제나 하나!
# 날이 안맞았는지애들데리고는갈곳은 아니네요 발닿는 곳은 모래가 많이 일어서 안보이고요 깊은데는 파도가 있어서 겁쟁이는 10분만에 철수했습니다. 중간중간 돌있어서 워터슈즈 필수입니다
# 221217 / 코난해변 4
# 아이코난!
# 물 그리 맑은편은 아닙니다. 근데 아직까지는 방문해도 괜찮은 정도에요. 해지면 바람이 많이 불어 앉아있기 힘듭니다. 그리고 물에서 자꾸 따가운 무언가에 찔리는 느낌이었어요. 그리고 저희는 운좋게 해변에서 돌고래 떼가 다니는걸 봤습니다.
# 나만알고싶고 쓰레기많아지는게.싫어서 1점 ㅋ
# 진짜 사랑한다면... 소문 내지맙시다.. 놀다갈땐 자기 쓰레기+1 꼼꼼하게 가져갑시다 좀... 주말에 가면 걍 거대한 쓰레기통.
# 장점: 물 엄청 맑음. 물고기도 엄청 많음. 스노쿨링하기 최적. 얕은곳과 깊은곳 공존.단점: 물벼룩많음. 이날만 유독 그랬나? 싶지만 따끔거리면 바로 나오기. 얕은곳고ㅓ 깊은곳 격차가 좀 심한편. 돌이 바닥에 좀 있어서 맨발은 비추. 파라솔 의자 그런거 없음. 샤워실은 월정리까지 가야함. 간단한 튜브 구명조끼 스노쿨링장비는 앞에 중식당에서 대여가능. 근데 물량은 많지 않음.
# 인생스노쿨링👍👍👍👍제발 쓰레기버리지말고 오래오래 써요8살아이도 바다아프다며 패트병주워오네요ㅜ
# 극락
# 멋집니다^^
# 살인사건 나기 딱 좋은 네이밍 센스네
# 제이름은 코난 탐정이죠
# 아~ 오늘도 사건이 끝났으니 맥주를 마시러 가자고아저씨 죄송해요!(푸슉)어엉~ 오늘도 잠이 옵니다아~
# 스노클링 하기 좋아여물고기 생각보다 많습니다.
# 물은 맑은데떠내려온 쓰레기, 악취가 너무 고약합니다.
# 바위쪽에 물고기 많이봤어요 ㅎㅎ안전요원 계셨고 화장실,샤워실,탈의실 따로 없습니다다함께 뒷처리 깔끔하게해서 재밌게놀아요‼️
# 물이 맑아서 스노쿨링하기 좋아요구좌에서 한달 지내는 동안 여기서만 세번 물놀이했슴당!
# 신지츠와 이츠모 히토츠!
# 작은 해변이예요 화장실 x 탈의실 x 샤워실 x물은 좋아요 이쁨
# 물색 이쁘고 물고기 많아요. 다만, 제주시에서 공식 지정한 해수욕장이 아니어서 안전요원/화장실/기타 편의시설 아무것도 없어요
# 너무 멋진곳 입니다. 물색이 제주도에서 최고로 이뻐요.
# 한산하고 좋은데 미역과 쓰레기 때문에ㅠㅠㅠ스노클링 스팟이라고 해서 갔는데 벌레도 많고 지저분해서 못즐겼어요.
# 아니온듯 다녀가소서~
# 한가하긴 해요.어른들이 돗자리 펴 놓고 한가롭게 풍경 보기엔 좋아요.실제로 가면 옹기종기 앉아서 지평선 보며 담소를 나눈다거나 노래 부르거나 하고 있어요.아이들과 놀 곳을 찾으신다면 여기보다 김녕 또는 함덕으로 가시면 더 좋을 듯 합니다.
# 여기 진짜 숨은 공간이었는데.. 결국 알려져버렸네요..ㅜㅜ 엉망이 됐어요..너무 아까운곳.....
# 인스타감성충 캠핑충들 몰려와서 또 쓰레기장만들어놓고갔네요 곳곳에 깨진술병과 쓰레기더미 불피우고난 재 천지입니다
# 4 . 논짓물해변
# 지금은 추워서 못들어가지만 구경하긴 좋은곳
# 물진짜 더러워서 다시는 안가요
# 물도탁하고 별루임
# 돌로 둘러 싸여있어서 안전하게 놀수있어요담수가 계속 흘러나와서 엄청 시원하고바닷물도 덜짭니다해수욕장 모래날리는거 싫으면 여기 강추
# 용천수로 물을 담아 만든 물놀이장. 3단계인데. 가까울수록 민물이고 완전 외곽은 바닷물. 물이 시원하고 수심도 앝아서 애기들 물놀이 장으로 적합.
# 장점1. 파도 없어서 초딩 10살 이상의 청소년들 놀기 좋음2. 담수 나오는 곳에서 몸 헹구고 나오기 좋음3. 만조 1시간 전에 오면 뷰 맛집단점1. 고인물이라 부유물 너무 많음. 차리리 바닷물 해초가 나음...2. 물이 너무 차가움. 유아들 놀기에는 얼음물임.3. 바닥에 바위, 돌, 이끼가 많아 미끄럽고 날카로움. 아쿠아슈즈와 레깅스 필수4. 평상이 너무 다닥다닥 붙아있어 불편함. 옆테이블이 10명 대가족 왔는데 평상 하나 빌려놓고 음식 쓰레기 흘려서 바닥도 더러움5. 통로가 너무 좁음결론 : 사진만 찍고 갑시다
# 물 온도 적당하고 깊이 적당해 애들 놀기 좋음.
# 고기 구워먹으며 물놀이 할 수 있는 곳!민물과 바닷물이 만나는 곳이라 물 때를 잘 맞추면 민물에서만 놀 수도 있어 좋다 :)
# 서귀포 바다 전체가 중국발 쓰레기유입으로 몸살을 앓고 있는거에 비하면.. 상대적으로 덜(?) 더러운 담수욕장 입니다. 물빠지기 시작하는 때 맞추어 가면 수질 괜찮구요. 담수가 계속 나오고있어 조금은 물관리되는듯 합니다.한낮에는 물이 분수처럼 쏘아져나와 신나요 !성인허리정도 높이까지 물이 차있어요모래사장이 없다는게 아쉽고.. 근처매점 비싸지만 자릿세가 하루에 3만으로 저렴했어요인피니티풀장 같은 사진을 얻을수 있어요 !
# 난드르쉼터~논짓물해변이 잘 알려지진 않고 상당히 좁은 산길이지만 멋진 드라이브코스입니다.  막상 차로 가면 제대로 된 길도 아닌 거 같고 산으로 막 올라가서 여기 차로 갈 수 있나? 의문이 드는데 갈 수 있습니다.  길이 좁으니 조심조심 천천히 가시고 무조건 반시계방향으로 가세요.  대략 3키로 길이인데 괜찮습니다.  특히 중간 정상에 팔길이라는 예쁜 카페가 있는데 거기가 최고의 경치입니다.  그리고 논짓물해변 주차장에 편의점과 카페가 잘 챙겨줘서 그런지 길냥이들이 엄청 많습니다.
# 너무 아름다움ㅜㅜㅜ
# 코로나 4단계로 폐장 ㅠㅠ
# 바다를 지켜주세요. 쓰레기가 곳곳에 보여요:(
# 이런거 잘 안쓰지만 해도 해도 너무해서 씁니다 물은 부유물이 둥둥 떠다니고 주변에는 쓰레기가 넘쳐나는데도 치우는 사람은 없고 평상 대여료 3만원 내고 싶지 않아 자리 필 자리 알아보니 그럴만한 자리 없어 평상 빌렸는데 주변엔 쓰레기 가득 다신 오고 싶지 않습니다
# 낫베드입니다
# 깨끗한 용천수가 계속 공급되어 물도 맑고 덜 짜서 좋고 차박하기 조용합니다
# 수영장x, 화장실 위생최악 안들어가는게 정신건강에 좋음, 관리x,  그냥 바다 풍경보기엔 좋아요.
# 리뷰사진보고 친구들하고 다같이갔는데 왠걸;;왠 고인물있는 곳이네요..안에 쓰레기도 있었고 이끼때문에 바닥은 디게미끄러워요.. 이상적인 해수욕장보단 그냥 수영장에가까운 느낌..
# 똥물.... 아쉽 ㅠㅠ
# 시원해요~~~
# 들렁궤까지 잠깐 걸음. 들렁궤쪽이 도민 낚시 포인트인거같다. 돌이 판판하게 잘 나있는데 쭉이어져있다. 모래사장아니고 돌바닥. 바다가 깔끔한편이다. 논짓물에는 바다에 인피니트 수영장처럼 만들어 놓은 곳이 있는데 여름에 자릿세를 받고 빌려주는 것 같다. 특별하진않고 그냥 숨겨진 도민 포인트같아보임
# 날씨 풀리면 꼭 다시와서 수영하고싶어요ㅠ
# 갈대랑 바다 너무 이쁘네용
# 좋아요
# 민물과 바닷물이 함께하는곳 강추입니다.
# 3단 수영장, 아쿠아슈즈 필수. 물이 아주 시원합니다.
# 지나가다 우연히 발견. 여름에는 수영도 할 수 있는거 같아요. 한적하니 좋아요 부대시설도 나름 괜찮음
# 5 . 검멀레해변
# 23개월 여아 동반순환 버스를 타고 급하게 구경 하였습니다 경관이 너무 이쁘고 좋았지만 비오고 바람이 많이 불어 힘들었어요 ㅎ
# 경관은 너무 아름다운 곳입니다. 쓰레기가 좀 많이 방치되어 있다는게 한가지 아쉬운 점입니다.
# 멋진 해변입니다. 보트가 재밌긴 하겠지만, 계속 한 가운데 가만히 떠있어서 경치를 해치네요. 운행 안 할 때는 선착장에 있었으면!
# 서빈백사 이후로 좋아하는 두번째 해변검은 모래가 너무 신기했던듯 함옛날에는 별거 없었지만 지금은 카페도 많이 생기고 활기 넘침
# Stop for a peanut ice cream at Jimmys and enjoy the cliffside views
# https://youtu.be/wJBM7jd_4Ucok차박 우도총정리유튜브 검색하시면 동영상 올렸습니다
# 아름다운한국bb
# 멀리서 보아야 이쁘다절대 그냥 지나쳐서 그런건 아닌데..내려가는 길이 헬같아보이던데.. 맞나요? 자전거타고 다녀서 허벅지 너무아파서 계단은..앙대..
# 멋있긴 하지만 엄청 기억에 남지는 않는
# 해변가에 쓰레기 너무 많음. 바다도 백퍼 똥물
# 멋있음
# 너무 너무 멋있다! 성산일출봉이랑 비슷해요
# 장관이네
# 야 인간적으로 에스컬레이터 하나 만들자이게 뭐냐 진짜날도 더운데 밑에 내려가고 싶겠냐고안그래?먹은거 다 토하고싶어지더라풍경은 좋아서 2스타 준다
# 여기진짜 멋있다.. 서빈백사인가 거기보다 여기가 훨씬 멋잇다
# 자연의 위대함이네요 너무 멋있어요.. 또 다음에 올께 안녕 ㅎㅎ 아름다운 우도!
# 진짜좋은 검멀레
# 검은모래와 자갈이 인상적이에요. 검멀레해변 앞에 있는 보트 타고 후해석벽, 동안경굴, 주간명월을 모두 볼 수 있는데 추천합니다!
# 아름댭습니댜요 ,, 압도당하는 느낌⛰
# 내려오는길 둘레길 이정표가 없어서 길잃을뻔했네요ㅠ
# 보트 추천!!!!!! 꼭 타세요!! (현금 15000)
# 꼭 들르는 명소같은 곳
# 우도가면 꼭 들러서 사진 한장 박기 좋은곳입니다..바로 앞 우도 땅콩 아이스크림 5천원 좀 비싸지만....한번쯤은 머...
# 1 . 몽돌해변
# 눈을 감고 몽돌이 파도에 굴러가는 소리를 들어보세요+여기는 해수욕장이 아닙니다.. 탁트인 바다를 바라시는 분께는 비추입니다. 밤바다 산책으로 생각하고 오시면 만족하실거에요 :)+ 일년만에 다시 와보니 몽돌이 많이 유실되었고 한쪽에만 많이 있네요ㅠㅠ
# 공항에서 멀지도않고 갈때마다 좋아요 이호해변도 같이 들렸다 드라이브코스 하면 굿~!
# 쓰레기가 너무 많아요 ㅜㅜ
# 몽돌 없음..
# 발 마이아픔 그티만 바다소리 너무 좋은 것
# 지금공사중 7.14일기준바다접근안되요
# ASMR이 엄청 좋은 해변, 아무것도 없지만 아무것도 하지않고 멍하니 있기 좋다.6월17일 기준 공사중
# 별거 없다고 느끼실 수 있지만 파도에 돌 굴러가는 소리가 너무 이뻐서 한참 있다 왔던곳이예요 (4년전)
# 여기가 이름붙은 해변이 맞는교? 어리둥절관광지는 아닌듯 내려가는 길도 없고 찻길 한복판에 덜렁 있음
# 이뽀요 바다 소리도 듣기 좋습니다.
# no more reviews to load
# 2 . 세기알해변
# 물은 깨끗한데 모래때문에 스노쿨링은 불가능합니다.
# 바글바글 됨. 내 최애 해변이었는데 어떻게 소문이 났는지 올해부터 관광객이 많아짐..... 작년까지는 한여름에 가도 이 정도로 사람 많진 않았는데 너무 슬프다.
# - 김녕 옆 자그마한 해변- 방파제 옆 스노쿨링 포인트- 크고 작은 물고기 많음- 백사장 주변 수심 깊지 않아 아이들 놀기도 굿
# 김녕바다색은 말이 필요없어요~날씨좋을땐 정말 환상적이예요^^
# 진짜 이쁩니다
# 제주 바다중 젤 이쁘고 깨끗함 ㅎㅎ
# ♡
# 김녕은 물이 얕아 아가들 놀기좋고 여기는 파도타기하기 좋은 듯해요
# 평범한 듯 주변 동네가 예뻐서 좋았어요 ㅎㅎㅎ
# 기대 안하고 갔는데 너무 이뻣어요김녕은 이미 유명하고 사람많은데 세기알은 그렇게 알려진 곳이 아니라 사람도 적고 ㅎㅎ 아이들이랑 놀기 좋았어요^,^
# no more reviews to load
# 3 . 신흥해수욕장
# 꼭 다시와서 차박을 해보고 싶은 보물같은 곳정말.다시오고 싶어요
# https://youtu.be/7XjB8jFg5LYok차박 신흥해수욕장 유튜브 검색하시면 동영상 올렸습니다 한달 이상살고 설갔다오면 제일먼저들러쉬는곳 너무좋은곳. 바다가 이쁘다
# 잔잔한 물결
# 주차장 옆 숨은 해양 맛집
# 영유아 핫스팟. 얕고 맑고 파도없음.
# 조용한 바당
# 작은 해변
# 물빠졌을때 갔는데진심 몰디브온줄..
# 후기보고 깨끗하고 조용할꺼란 기대를 안고 갔으나 더러움. 사람은 별로 없긴하지만 엄청 좁은 해변이고  더러워서 사람 없는듯. 모래사장에 쓰레기 엄청 많고 물에도 부유물 둥둥 떠다님. 그리고 바다물 속에 무슨 관이 설치돼어있음. 양식장에서 쓰는 관인지 그게 모래바닥에 훤히 다 드러나 있음.
# 한적한 여유가 있는 곳
# 기대 없이 왔는데 좋아요ㅎ
# 델문도 카페....사람 엄청많이몰리고 지저분하고해서 테이크아웃해서 도망쳤음ㅠ근디 한적하고 아기자기한 이곳에서 힐링받고있다♡ 밑에 한명리뷰보고 그냥욌는데...진짜 화장실 겁나깨끗함 ㅋㅋㅋ차량이 우리꺼한대뿐 ㅋㅋㅋㅋ
# 사람도 없고 화장실도 깨끗하고
# no more reviews to load
# 4 . 하모해변
# https://youtu.be/GT816atwjH4ok차박 하모해수욕장 검색하시면 동영상 올렸습니다 화장실 샤워실도 무참하게 방치 그래도 말가족보고 위안..
# 화장실 폐쇄되었어요~! 참고하세요~!!화장실 이전 안내표시붙어있고 사용할수없어요~!옆에 운진항 여객선대합실 화장실로 가야합니다.정보필요하신분 있을까봐 헛걸음하지마시라고 올려봐요~
# 최악. 화장실 개더럽고 막혔음.  똥파리 날리고 밤에 문신한  ♩♬♪들 술처먹고 노래부르고 다신 안감.아침엔 아줌마들이 애완견 데리고 해변나와서 개 똥싸고 오줌 누고 애완견들 줄도 안메고 다니고.동네 민심도 거지같음. 야영데트는 제주도민들이 죄다 자리맡아 놓고 주말마다 와서 술처먹고 담배피고 고성방가하고 그냥 제주도민 끼리끼리 모여 노는 해수욕장.. 해변 모래가 개똥와 개오줌이 섞인곳 이라 보면 될듯.
# 야영장폐쇄. 취사. 야영금지.ㅡㅡ집앞이라 좋았는데. 짜증난다.쓰레기는 가져가세요. 제발.ㅡㅡ
# 올레길 걸어가며 들린 곳이에요정말 바다가 아름다워서 넋을 놓고 쳐다봤습니다
# 사람없어 좋은데 화장실 더럽고 샤워실 없음
# 한적하게 수영하기 좋음
# 스노쿨링 하기 좋은 곳이란 말에 꽂혀서 이주변에서 했는데 비추합니다.
# 스노쿨링하고싶은곳
# 조용하고 다른곳보다 파도도 잔잔한듯본격물놀이보단 아이들이오면 좋을듯영업용파라솔이 없고잔디밭도있어 텐트치기는 좋을듯그늘이없고 해변내 흰건물파란지붕이 화장실
# 오면 꼭들리는 작고 조용한 해변
# no more reviews to load
# 5 . 알작지해변
# 몽돌 알이 작아서 알작지엌ㅋㅋㅋㅋㅋ
# 가죽구두 신고 내려가면 다 긁히고 찢어지고 기스나고 난리나여ㅋ조심하시길ㅋㅋ그리고 도로가에 주차 많이해서 도로가 좁아지고 식당들 앞 창문 다가리고... 그리고 주차한 차 안에서 놀더라구요 여튼 관광객때문에 동네 풍경이 별로에요
# 풍경 좋아요♥️
# 제주에 워낙 멋진 바다가 많아서 생각보단 별로였어요. 몽돌이라 놀기 좋진 않고 사람없이 한적해서 잠깐 사진찍으며 구경하긴 괜찮았습니다.
# 완전 한적한 검은 모래 몽돌 해변이에요.
# 조용하고 좋아요^^
# 이끼와 벌레만 가득한 곳....공사중임 ㅠㅠ
# 공사중이라 접근이 힘듬..지저분사진찍어놓은건 멋지네
# no more reviews to load
# 1 . 함덕해수욕장 주차장
# 주차장 넓고 좋습니다
# no review in crawling
# no more reviews to load
# 2 . 협재해수욕장 주차장
# 협재해수욕장의 유명세에비해 주차공간이 너~~무 부족합니다ㅠ
# 주차공간 협소, 극혐
# 이렇게 밝은 해수욕장 처음인데 모래사장이 다이아몬드같이 빛나요너무밝아서 썬구리 안챙겨갔다가 낭패봤네요멀리서볼땐 눈이 부시다가 사진찍으면서 울었네요이후로 홍채인식도 안되고 팔은 다타버렸어요썬구리 꼭 챙겨가시길
# 주차장 공간이 넓어서 초보도 안심주차 가능해요 차 사이 간격도 넓고 통로도 넓어요 여기 차대고 한림공원 가기도 가까워서 좋아요
# no more reviews to load
# 3 . 협재해수욕장 캠핑장
# 고운 모래사장이 넓다.
# 해수욕장이 갑자기 깊어지지 않아서 좋아요! 물도 따뜻하고….
# 때깔은협재보다함덕해변이더예뻐보이는
# 비양도 뷰, 미역자란 바위들, 바다색 예뻐요바로 앞쪽 상업시설 노래가 커서 아쉬워요주차장하고 바다 거리가 조금 있어요발 씻는 공간있어서 편리해요!
# no more reviews to load
# 4 . 곽지해수욕장 주차장
# 해수욕한번하고오면주차료 후덜덜합니다재활용도움센터 주차장 무료고널널합니다거리도 여기랑 별반 차이없어요
# 입출차 시에 번호판이 찍히긴 하는데 비용을 내는 구조는 아니네요…물론 성수기에는 아닐 수도 있지만 22년 5월에는 무료입니다.
# no review in crawling
# no more reviews to load
# 5 . 세화해수욕장 주차장
# no review in extract
# no review in crawling
# no more reviews to load
# 1 . 김녕해수욕장 야영장주차장2
# no review in extract
# no review in crawling
# no more reviews to load
# 2 . 삼양해수욕장 정자
# 삼양해수욕장끝부분의 올레길 18코스의 중간 스텡프찍고 잠시 쉬어가기 좋은곳~
# 올레길 18코스 중간스탬프 지점
# no review in crawling
# no more reviews to load
# 3 . 삼양해수욕장 공영주차장
# 주차장아니고 발씻는곳과 화장실입니다
# no review in crawling
# no more reviews to load
# 4 . 하도해수욕장 화장실
# 관리가 안된다
# 지금 공사중이래요~ 입구 막아져있어요~ 4월 27일까지라니 화장실 검색하시는분들 참고하시라고 올려봐요~
# no review in crawling
# no more reviews to load
# 5 . 이호테우해수욕장 화장실
# https://youtu.be/R4hXLXd9s9Aok차박 이호태우해수욕장 유튜브 검색하시면 동영상 올렸습니다 낮과밤의 다른모습
# no review in crawling
# no more reviews to load
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# 제주도 해수욕장_reviews.csv saved.
# finish

# %%
import os
from time import sleep
import pandas as pd

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')
chromedriver_path = "C:/chromedriver"
driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)

def search(place):
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')
    search_area.send_keys(place)
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)
    sleep(1)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem')

    crawling(place, place_lists[:5])
    search_area.clear()

    try:
        driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
        sleep(1)

        for i in range(2, 6):
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
            sleep(1)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            place_lists = soup.select('.placelist > .PlaceItem')

            crawling(place, place_lists[:5])

    except ElementNotInteractableException:
        print('not found')
    finally:
        search_area.clear()

def crawling(place, place_lists):
    global driver, all_data

    for i, place in enumerate(place_lists):
        place_name = place.select('.head_item > .tit_name > .link_name')[0].text

        detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
        driver.find_element_by_xpath(detail_page_xpath).send_keys(Keys.ENTER)
        driver.switch_to.window(driver.window_handles[-1])
        sleep(1)

        print(i+1, '.', place_name)        
        
        data_dict = extract_data()

        if data_dict:
            all_data.append(data_dict)

        driver.close()
        driver.switch_to.window(driver.window_handles[0])

def find_element(xpath):
    global driver

    try:
        element = driver.find_element_by_xpath(xpath)
        return element.text
    except NoSuchElementException:
        return ""

def extract_data():
    global driver

    place_name = find_element('//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/h2')
    place_location = find_element('//*[@id="mArticle"]/div[1]/div[2]/div[1]/div/span[1]')
    place_feature = find_element('//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/span[1]')
    place_star =  find_element('//*[@id="mArticle"]/div[5]/div[1]/div/em')
    operating_time = find_element('//*[@id="mArticle"]/div[1]/div[2]/div[2]/div/div[1]/ul/li/span/span[1]')

    crawling_data = [place_name, place_location, place_feature, place_star, operating_time]
    
    if place_name:
        data_dict = {"place_name": place_name,
            "place_location": place_location,
            "place_feature": place_feature,
            "place_star": place_star,
            "operating_time": operating_time}
        return data_dict, print(crawling_data)
    else:
        return None

def main():
    global driver, all_data
    all_data = []
    driver.implicitly_wait(1)
    driver.get('https://map.kakao.com/')
    
    place_infos = [input("")]
    place_infos_str = "".join(place_infos)

    for i, place in enumerate(place_infos):
        if i % 4 == 0 and i != 0:
            sleep(1)
        search(place)

    driver.quit()
    print("finish")

    # Save all_data to a CSV file
    if all_data:
        data_frame = pd.DataFrame(all_data)
        data_frame.to_csv(f"{place_infos_str}_reviews.csv", index=False, encoding='utf-8-sig')
        print("Data saved to top_25_places_data.csv")
    else:
        print("No data to save")

if __name__ == "__main__":
    main()

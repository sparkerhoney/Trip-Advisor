# %%
import os
from time import sleep

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')
##############################################################  ############
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')
chromedriver_path = "C:/chromedriver"
driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기

def main():
    global driver, load_wb, review_num

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

    # 검색할 목록
    place_infos = ['제주도 관광지']

    for i, place in enumerate(place_infos):
        # delay
        if i % 4 == 0 and i != 0:
            sleep(5)
        print("#####", i)
        search(place)

    driver.quit()
    print("finish")
    
def search(place):
    global driver

    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem') # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, place_lists)
    search_area.clear()

    # 우선 더보기 클릭해서 2페이지
    try:
        driver.find_element_by_xpath('//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
        sleep(1)

        # 2~ 5페이지 읽기
        for i in range(2, 6):
            # 페이지 넘기기
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
            sleep(1)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            place_lists = soup.select('.placelist > .PlaceItem') # 장소 목록 list

            crawling(place, place_lists)

    except ElementNotInteractableException:
        print('not found')
    finally:
        search_area.clear()
        
def crawling(place, place_lists):
    
    while_flag = False
    for i, place in enumerate(place_lists):
        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address
        element = driver.find_element(By.XPATH, '//*[@id="info.search.place.list"]/li[2]/div[5]/div[2]/p[2]').text
        
        
        detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
        driver.find_element_by_xpath(detail_page_xpath).send_keys(Keys.ENTER)
        driver.switch_to.window(driver.window_handles[-1])  # 상세정보 탭으로 변환
        sleep(1)

        print('####', place_name + element)
        
        # 첫 페이지
        extract_data(place_name)

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환
        
def extract_data(place_name):
    global driver

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 관광지 분류    
    place_feature = soup.find('//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/span[1]/text()})
# //*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/span[1]/text()
    print(place_feature)
    
    return place_feature

if __name__ == "__main__":
    main()
# Out:
# ##### 0
# #### 올레길 7코스(서귀포-월평 올레)
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21804\2630874367.py in <module>
#     119
#     120 if __name__ == "__main__":
# --> 121     main()
#
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21804\2630874367.py in main()
#      35             sleep(5)
#      36         print("#####", i)
# ---> 37         search(place)
#      38
#      39     driver.quit()
#
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21804\2630874367.py in search(place)
#      56
#      57     # 검색된 첫 페이지 장소 목록 크롤링하기
# ---> 58     crawling(place, place_lists)
#      59     search_area.clear()
#      60
#
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21804\2630874367.py in crawling(place, place_lists)
#      99
#     100         # 첫 페이지
# --> 101         extract_data(place_name)
#     102
#     103         driver.close()
#
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21804\2630874367.py in extract_data(place_name)
#     112     # 관광지 분류
#     113     place_feature_info = soup.find('div', {'class': 'location_evaluation'})
# --> 114     place_feature = place_feature_info.select('.txt_location > .span[1]')
#     115 # //*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/span[1]/text()
#     116     print(place_feature)
#
# ~\anaconda3\lib\site-packages\bs4\element.py in select(self, selector, namespaces, limit, **kwargs)
#    1971             )
#    1972
# -> 1973         results = soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    1974
#    1975         # We do this because it's more consistent and because
#
# ~\anaconda3\lib\site-packages\soupsieve\__init__.py in select(select, tag, namespaces, limit, flags, custom, **kwargs)
#     142     """Select the specified tags."""
#     143
# --> 144     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#     145
#     146
#
# ~\anaconda3\lib\site-packages\soupsieve\__init__.py in compile(pattern, namespaces, flags, custom, **kwargs)
#      65         return pattern
#      66
# ---> 67     return cp._cached_css_compile(pattern, ns, cs, flags)
#      68
#      69
#
# ~\anaconda3\lib\site-packages\soupsieve\css_parser.py in _cached_css_compile(pattern, namespaces, custom, flags)
#     216     return cm.SoupSieve(
#     217         pattern,
# --> 218         CSSParser(
#     219             pattern,
#     220             custom=custom_selectors,
#
# ~\anaconda3\lib\site-packages\soupsieve\css_parser.py in process_selectors(self, index, flags)
#    1157         """Process selectors."""
#    1158
# -> 1159         return self.parse_selectors(self.selector_iter(self.pattern), index, flags)
#    1160
#    1161
#
# ~\anaconda3\lib\site-packages\soupsieve\css_parser.py in parse_selectors(self, iselector, index, flags)
#     983         try:
#     984             while True:
# --> 985                 key, m = next(iselector)
#     986
#     987                 # Handle parts
#
# ~\anaconda3\lib\site-packages\soupsieve\css_parser.py in selector_iter(self, pattern)
#    1150                 else:
#    1151                     msg = "Invalid character {!r} position {}".format(c, index)
# -> 1152                 raise SelectorSyntaxError(msg, self.pattern, index)
#    1153         if self.debug:  # pragma: no cover
#    1154             print('## END PARSING')
#
# SelectorSyntaxError: Malformed attribute selector at position 21
#   line 1:
# .txt_location > .span[1]
#                      ^
